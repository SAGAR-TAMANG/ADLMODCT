# %% [markdown]
# MobileNetV3

# %%
import os
import numpy as np
import json
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import math
from sklearn.utils import class_weight

# --- 1. Configuration for this Experiment ---
MODEL_CHOICE = "MobileNetV3Large"
INPUT_SIZE = 224
BATCH_SIZE = 8  # Best performing batch size for MobileNet family
INITIAL_LR = 1e-4  # A stable learning rate for the initial stage
FINE_TUNE_LR = 1e-5 # A very low learning rate for the fine-tuning stage
FEATURE_EXTRACTION_EPOCHS = 50
FINE_TUNE_EPOCHS = 50
PATIENCE = 15 # Increased patience for more stable training
RESULTS_DIR = 'results'
MODEL_NAME = f'{MODEL_CHOICE}_ultimate_finetune_bs{BATCH_SIZE}'
model_results_dir = os.path.join(RESULTS_DIR, MODEL_NAME)
os.makedirs(model_results_dir, exist_ok=True)

print("="*80)
print(f"--- Starting Ultimate Experiment for: {MODEL_NAME} ---")
print("Strategy: Hybrid Training with Class Weights, Augmentation, and Fine-Tuning")
print("="*80)

# --- 2. Data Loading ---
PROCESSED_DIR = os.path.join('processed_data', 'BrinjalFruitX')
print(f"\nLoading preprocessed data from '{PROCESSED_DIR}'...")
try:
    X_train = np.load(os.path.join(PROCESSED_DIR, 'X_train.npy'))
    y_train = np.load(os.path.join(PROCESSED_DIR, 'y_train.npy'))
    X_val = np.load(os.path.join(PROCESSED_DIR, 'X_val.npy'))
    y_val = np.load(os.path.join(PROCESSED_DIR, 'y_val.npy'))
    X_test = np.load(os.path.join(PROCESSED_DIR, 'X_test.npy'))
    y_test = np.load(os.path.join(PROCESSED_DIR, 'y_test.npy'))
    with open(os.path.join(PROCESSED_DIR, 'class_names.json'), 'r') as f:
        class_names = json.load(f)
    print("Data loaded successfully.")
except FileNotFoundError:
    print(f"ERROR: Data not found at {PROCESSED_DIR}.")
    exit()

# --- 3. Model Definition and Training ---

# --- Data Augmentation Layer ---
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2)
], name="data_augmentation")

# --- Base Model ---
base_model = MobileNetV3Large(input_shape=(INPUT_SIZE, INPUT_SIZE, 3), include_top=False, weights='imagenet')

# --- STAGE 1: STABLE FEATURE EXTRACTION ---
print("\n--- STAGE 1: STABLE FEATURE EXTRACTION ---")
base_model.trainable = False

inputs = layers.Input(shape=(INPUT_SIZE, INPUT_SIZE, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(len(class_names), activation='softmax')(x)
model = models.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=INITIAL_LR),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Training the classification head...")
history = model.fit(
    X_train, y_train,
    epochs=FEATURE_EXTRACTION_EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_val, y_val),
    callbacks=[EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True, verbose=1)]
)

# --- STAGE 2: ADVANCED FINE-TUNING ---
print("\n--- STAGE 2: ADVANCED FINE-TUNING ---")

# --- Calculate Class Weights (introduced only in Stage 2) ---
print("\nCalculating class weights for fine-tuning...")
class_labels = np.unique(y_train)
weights = class_weight.compute_class_weight('balanced', classes=class_labels, y=y_train)
class_weights_dict = dict(zip(class_labels, weights))
print("Class Weights:", class_weights_dict)

# --- Unfreeze layers for fine-tuning ---
base_model.trainable = True
fine_tune_at = math.ceil(len(base_model.layers) * 0.5) # Unfreeze top 50%
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False
print(f"Unfreezing from layer {fine_tune_at} onwards.")

# --- Re-compile with a very low learning rate ---
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# --- Callbacks for the fine-tuning stage ---
checkpoint_path = os.path.join(model_results_dir, 'best_model.keras')
callbacks_finetune = [
    EarlyStopping(monitor='val_loss', patience=PATIENCE + 5, verbose=1),
    ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1, min_lr=1e-7)
]

print("Fine-tuning the model with class weights and a low learning rate...")
total_epochs = history.epoch[-1] + 1 + FINE_TUNE_EPOCHS
history_fine_tune = model.fit(
    X_train, y_train,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1] + 1,
    batch_size=BATCH_SIZE,
    validation_data=(X_val, y_val),
    class_weight=class_weights_dict, # Introduce class weights here
    callbacks=callbacks_finetune
)

# Load the best model saved during fine-tuning
model = tf.keras.models.load_model(checkpoint_path)

# --- 4. Evaluation and Saving ---
print(f"\n--- {MODEL_NAME} Final Test Set Evaluation ---")
y_pred_test_probs = model.predict(X_test)
y_pred_test_classes = np.argmax(y_pred_test_probs, axis=1)
report_dict = classification_report(y_test, y_pred_test_classes, target_names=class_names, output_dict=True)
print("\nTest Set Classification Report:\n")
print(classification_report(y_test, y_pred_test_classes, target_names=class_names))

# (The rest of the saving and summary code is the same)
report_df = pd.DataFrame(report_dict).transpose()
report_df.to_csv(os.path.join(model_results_dir, 'classification_report.csv'))

cm = confusion_matrix(y_test, y_pred_test_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title(f'{MODEL_NAME} Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.savefig(os.path.join(model_results_dir, 'confusion_matrix.png'))
plt.close()

print("\nUpdating summary results file...")
summary_file = os.path.join(RESULTS_DIR, 'summary_results.csv')
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
summary_data = {
    'model_name': MODEL_NAME,
    'batch_size': BATCH_SIZE,
    'test_accuracy': f"{test_accuracy:.4f}",
    'test_loss': f"{test_loss:.4f}",
    'macro_avg_f1-score': f"{report_dict['macro avg']['f1-score']:.4f}",
    'weighted_avg_f1-score': f"{report_dict['weighted avg']['f1-score']:.4f}"
}
new_results_df = pd.DataFrame([summary_data])
if os.path.exists(summary_file):
    summary_df = pd.read_csv(summary_file)
    if MODEL_NAME in summary_df['model_name'].values:
        summary_df.loc[summary_df['model_name'] == MODEL_NAME] = new_results_df.iloc[0].values
    else:
        summary_df = pd.concat([summary_df, new_results_df], ignore_index=True)
    summary_df.to_csv(summary_file, index=False)
else:
    new_results_df.to_csv(summary_file, index=False)

print(f"\n--- Experiment for {MODEL_NAME} is complete. Best model saved to {checkpoint_path} ---")
# Out:
# ================================================================================
# --- Starting Ultimate Experiment for: MobileNetV3Large_ultimate_finetune_bs8 ---
# Strategy: Hybrid Training with Class Weights, Augmentation, and Fine-Tuning
# ================================================================================
#
# Loading preprocessed data from 'processed_data\BrinjalFruitX'...
# Data loaded successfully.
#
# --- STAGE 1: STABLE FEATURE EXTRACTION ---
# Training the classification head...
# Epoch 1/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 17s 78ms/step - accuracy: 0.2751 - loss: 1.6719 - val_accuracy: 0.4033 - val_loss: 1.4530
# Epoch 2/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.3632 - loss: 1.5562 - val_accuracy: 0.4033 - val_loss: 1.4331
# Epoch 3/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 66ms/step - accuracy: 0.3516 - loss: 1.5756 - val_accuracy: 0.4033 - val_loss: 1.4276
# Epoch 4/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.3394 - loss: 1.5812 - val_accuracy: 0.4033 - val_loss: 1.4267
# Epoch 5/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.3634 - loss: 1.5103 - val_accuracy: 0.4033 - val_loss: 1.4265
# Epoch 6/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.3557 - loss: 1.5213 - val_accuracy: 0.4033 - val_loss: 1.4251
# Epoch 7/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.3895 - loss: 1.5016 - val_accuracy: 0.4033 - val_loss: 1.4243
# Epoch 8/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.3650 - loss: 1.5002 - val_accuracy: 0.4033 - val_loss: 1.4226
# Epoch 9/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.3764 - loss: 1.4813 - val_accuracy: 0.4033 - val_loss: 1.4220
# Epoch 10/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.3849 - loss: 1.4703 - val_accuracy: 0.4033 - val_loss: 1.4209
# Epoch 11/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.3820 - loss: 1.4811 - val_accuracy: 0.4033 - val_loss: 1.4203
# Epoch 12/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.3813 - loss: 1.4442 - val_accuracy: 0.4033 - val_loss: 1.4195
# Epoch 13/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.3711 - loss: 1.5034 - val_accuracy: 0.4033 - val_loss: 1.4190
# Epoch 14/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.3752 - loss: 1.4467 - val_accuracy: 0.4033 - val_loss: 1.4180
# Epoch 15/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4087 - loss: 1.4539 - val_accuracy: 0.4033 - val_loss: 1.4176
# Epoch 16/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.3976 - loss: 1.4786 - val_accuracy: 0.4033 - val_loss: 1.4166
# Epoch 17/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.4047 - loss: 1.4398 - val_accuracy: 0.4033 - val_loss: 1.4161
# Epoch 18/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.3994 - loss: 1.4432 - val_accuracy: 0.4033 - val_loss: 1.4154
# Epoch 19/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.4150 - loss: 1.4218 - val_accuracy: 0.4033 - val_loss: 1.4148
# Epoch 20/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4037 - loss: 1.4278 - val_accuracy: 0.4033 - val_loss: 1.4145
# Epoch 21/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.3990 - loss: 1.4483 - val_accuracy: 0.4033 - val_loss: 1.4136
# Epoch 22/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.4134 - loss: 1.4270 - val_accuracy: 0.4033 - val_loss: 1.4129
# Epoch 23/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.3940 - loss: 1.4423 - val_accuracy: 0.4088 - val_loss: 1.4123
# Epoch 24/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.3988 - loss: 1.4307 - val_accuracy: 0.4088 - val_loss: 1.4117
# Epoch 25/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.4104 - loss: 1.4266 - val_accuracy: 0.4088 - val_loss: 1.4110
# Epoch 26/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4108 - loss: 1.4261 - val_accuracy: 0.4033 - val_loss: 1.4110
# Epoch 27/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4267 - loss: 1.3996 - val_accuracy: 0.4088 - val_loss: 1.4100
# Epoch 28/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.3984 - loss: 1.4301 - val_accuracy: 0.4088 - val_loss: 1.4096
# Epoch 29/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4022 - loss: 1.4519 - val_accuracy: 0.4088 - val_loss: 1.4091
# Epoch 30/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.3899 - loss: 1.4619 - val_accuracy: 0.4088 - val_loss: 1.4090
# Epoch 31/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.3949 - loss: 1.4535 - val_accuracy: 0.4144 - val_loss: 1.4078
# Epoch 32/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4003 - loss: 1.4558 - val_accuracy: 0.4088 - val_loss: 1.4079
# Epoch 33/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - accuracy: 0.4201 - loss: 1.4187 - val_accuracy: 0.4199 - val_loss: 1.4065
# Epoch 34/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4283 - loss: 1.4331 - val_accuracy: 0.4199 - val_loss: 1.4058
# Epoch 35/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.3970 - loss: 1.4339 - val_accuracy: 0.4199 - val_loss: 1.4057
# Epoch 36/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4055 - loss: 1.4693 - val_accuracy: 0.4199 - val_loss: 1.4059
# Epoch 37/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4227 - loss: 1.4204 - val_accuracy: 0.4199 - val_loss: 1.4050
# Epoch 38/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4034 - loss: 1.4353 - val_accuracy: 0.4199 - val_loss: 1.4045
# Epoch 39/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.3909 - loss: 1.4368 - val_accuracy: 0.4199 - val_loss: 1.4042
# Epoch 40/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4132 - loss: 1.4387 - val_accuracy: 0.4199 - val_loss: 1.4043
# Epoch 41/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4251 - loss: 1.4179 - val_accuracy: 0.4199 - val_loss: 1.4035
# Epoch 42/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.4125 - loss: 1.4242 - val_accuracy: 0.4199 - val_loss: 1.4028
# Epoch 43/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.3891 - loss: 1.4343 - val_accuracy: 0.4199 - val_loss: 1.4024
# Epoch 44/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.3960 - loss: 1.4668 - val_accuracy: 0.4199 - val_loss: 1.4022
# Epoch 45/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.4365 - loss: 1.3986 - val_accuracy: 0.4254 - val_loss: 1.4016
# Epoch 46/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.4105 - loss: 1.4225 - val_accuracy: 0.4254 - val_loss: 1.4011
# Epoch 47/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.4250 - loss: 1.4397 - val_accuracy: 0.4254 - val_loss: 1.4007
# Epoch 48/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.3907 - loss: 1.4366 - val_accuracy: 0.4199 - val_loss: 1.4010
# Epoch 49/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 69ms/step - accuracy: 0.4322 - loss: 1.4110 - val_accuracy: 0.4254 - val_loss: 1.3999
# Epoch 50/50
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 11s 68ms/step - accuracy: 0.4212 - loss: 1.4112 - val_accuracy: 0.4254 - val_loss: 1.3994
# Restoring model weights from the end of the best epoch: 50.
#
# --- STAGE 2: ADVANCED FINE-TUNING ---
#
# Calculating class weights for fine-tuning...
# Class Weights: {np.int64(0): np.float64(1.8), np.int64(1): np.float64(0.7019498607242339), np.int64(2): np.float64(2.230088495575221), np.int64(3): np.float64(0.4970414201183432), np.int64(4): np.float64(1.7872340425531914)}
# Unfreezing from layer 94 onwards.
# Fine-tuning the model with class weights and a low learning rate...
# Epoch 51/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.1662 - loss: 1.9813
# Epoch 51: val_loss improved from inf to 1.40397, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 36s 145ms/step - accuracy: 0.1664 - loss: 1.9808 - val_accuracy: 0.4641 - val_loss: 1.4040 - learning_rate: 1.0000e-05
# Epoch 52/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.2444 - loss: 1.7430
# Epoch 52: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 126ms/step - accuracy: 0.2446 - loss: 1.7431 - val_accuracy: 0.4641 - val_loss: 1.4270 - learning_rate: 1.0000e-05
# Epoch 53/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.2892 - loss: 1.6862
# Epoch 53: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 124ms/step - accuracy: 0.2891 - loss: 1.6862 - val_accuracy: 0.2873 - val_loss: 1.4670 - learning_rate: 1.0000e-05
# Epoch 54/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3213 - loss: 1.5963
# Epoch 54: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 124ms/step - accuracy: 0.3213 - loss: 1.5965 - val_accuracy: 0.2873 - val_loss: 1.4984 - learning_rate: 1.0000e-05
# Epoch 55/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3422 - loss: 1.6217
# Epoch 55: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.3422 - loss: 1.6215 - val_accuracy: 0.2873 - val_loss: 1.5161 - learning_rate: 1.0000e-05
# Epoch 56/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.3570 - loss: 1.5097
# Epoch 56: val_loss did not improve from 1.40397
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 124ms/step - accuracy: 0.3569 - loss: 1.5101 - val_accuracy: 0.2873 - val_loss: 1.5625 - learning_rate: 1.0000e-05
# Epoch 57/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3404 - loss: 1.6189
# Epoch 57: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 124ms/step - accuracy: 0.3404 - loss: 1.6187 - val_accuracy: 0.2873 - val_loss: 1.6366 - learning_rate: 2.0000e-06
# Epoch 58/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3334 - loss: 1.5944
# Epoch 58: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.3335 - loss: 1.5944 - val_accuracy: 0.1436 - val_loss: 1.6869 - learning_rate: 2.0000e-06
# Epoch 59/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.3433 - loss: 1.6077
# Epoch 59: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 126ms/step - accuracy: 0.3433 - loss: 1.6077 - val_accuracy: 0.1492 - val_loss: 1.7256 - learning_rate: 2.0000e-06
# Epoch 60/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3587 - loss: 1.5462
# Epoch 60: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.3586 - loss: 1.5463 - val_accuracy: 0.1602 - val_loss: 1.7385 - learning_rate: 2.0000e-06
# Epoch 61/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3688 - loss: 1.5278
# Epoch 61: val_loss did not improve from 1.40397
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.3687 - loss: 1.5280 - val_accuracy: 0.1878 - val_loss: 1.7279 - learning_rate: 2.0000e-06
# Epoch 62/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.3371 - loss: 1.5925
# Epoch 62: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 126ms/step - accuracy: 0.3372 - loss: 1.5924 - val_accuracy: 0.2044 - val_loss: 1.7107 - learning_rate: 4.0000e-07
# Epoch 63/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3809 - loss: 1.5734
# Epoch 63: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 126ms/step - accuracy: 0.3809 - loss: 1.5734 - val_accuracy: 0.1823 - val_loss: 1.6879 - learning_rate: 4.0000e-07
# Epoch 64/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3485 - loss: 1.5773
# Epoch 64: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 124ms/step - accuracy: 0.3484 - loss: 1.5772 - val_accuracy: 0.1878 - val_loss: 1.6663 - learning_rate: 4.0000e-07
# Epoch 65/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3804 - loss: 1.5485
# Epoch 65: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.3802 - loss: 1.5487 - val_accuracy: 0.2044 - val_loss: 1.6496 - learning_rate: 4.0000e-07
# Epoch 66/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3589 - loss: 1.6149
# Epoch 66: val_loss did not improve from 1.40397
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1e-07.
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.3589 - loss: 1.6146 - val_accuracy: 0.2099 - val_loss: 1.6412 - learning_rate: 4.0000e-07
# Epoch 67/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3456 - loss: 1.6068
# Epoch 67: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.3457 - loss: 1.6065 - val_accuracy: 0.1768 - val_loss: 1.6406 - learning_rate: 1.0000e-07
# Epoch 68/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3370 - loss: 1.5700
# Epoch 68: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.3371 - loss: 1.5700 - val_accuracy: 0.1381 - val_loss: 1.6506 - learning_rate: 1.0000e-07
# Epoch 69/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3470 - loss: 1.5491
# Epoch 69: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.3470 - loss: 1.5492 - val_accuracy: 0.1381 - val_loss: 1.6614 - learning_rate: 1.0000e-07
# Epoch 70/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.3474 - loss: 1.5777
# Epoch 70: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.3474 - loss: 1.5776 - val_accuracy: 0.1436 - val_loss: 1.6700 - learning_rate: 1.0000e-07
# Epoch 71/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.3342 - loss: 1.5854
# Epoch 71: val_loss did not improve from 1.40397
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 20s 125ms/step - accuracy: 0.3343 - loss: 1.5853 - val_accuracy: 0.1768 - val_loss: 1.6761 - learning_rate: 1.0000e-07
# Epoch 71: early stopping
#
# --- MobileNetV3Large_ultimate_finetune_bs8 Final Test Set Evaluation ---
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 219ms/step
#
# Test Set Classification Report:
#
#                         precision    recall  f1-score   support
#
# Brinjal Fruit Creaking       0.00      0.00      0.00        40
#         Healty Brinjal       0.46      0.17      0.25       103
#       Phomopsis Bright       0.00      0.00      0.00        32
#  Shoot and Fruit Borer       0.43      0.97      0.60       145
#                Wet Rot       0.00      0.00      0.00        41
#
#               accuracy                           0.44       361
#              macro avg       0.18      0.23      0.17       361
#           weighted avg       0.31      0.44      0.31       361
# c:\Users\dr-basab\Desktop\Research Projects\ADLMODCT\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\dr-basab\Desktop\Research Projects\ADLMODCT\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\dr-basab\Desktop\Research Projects\ADLMODCT\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\dr-basab\Desktop\Research Projects\ADLMODCT\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\dr-basab\Desktop\Research Projects\ADLMODCT\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\dr-basab\Desktop\Research Projects\ADLMODCT\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Updating summary results file...
#
# --- Experiment for MobileNetV3Large_ultimate_finetune_bs8 is complete. Best model saved to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras ---

# %%
import os
import numpy as np
import json
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import math
from sklearn.utils import class_weight

# --- 1. Configuration for this Experiment ---
MODEL_CHOICE = "MobileNetV3Large"
INPUT_SIZE = 224
BATCH_SIZE = 8  # Best performing batch size for MobileNet family
INITIAL_LR = 1e-4  # A stable learning rate for the initial stage
FINE_TUNE_LR = 1e-5 # A very low learning rate for the fine-tuning stage
FEATURE_EXTRACTION_EPOCHS = 50
FINE_TUNE_EPOCHS = 50
PATIENCE = 15 # Increased patience for more stable training
RESULTS_DIR = 'results'
MODEL_NAME = f'{MODEL_CHOICE}_ultimate_finetune_bs{BATCH_SIZE}'
model_results_dir = os.path.join(RESULTS_DIR, MODEL_NAME)
os.makedirs(model_results_dir, exist_ok=True)

print("="*80)
print(f"--- Starting Ultimate Experiment for: {MODEL_NAME} ---")
print("Strategy: Hybrid Training with Class Weights, Augmentation, and Fine-Tuning")
print("="*80)

# --- 2. Data Loading ---
PROCESSED_DIR = os.path.join('processed_data', 'BrinjalFruitX_balanced')
print(f"\nLoading preprocessed data from '{PROCESSED_DIR}'...")
try:
    X_train = np.load(os.path.join(PROCESSED_DIR, 'X_train.npy'))
    y_train = np.load(os.path.join(PROCESSED_DIR, 'y_train.npy'))
    X_val = np.load(os.path.join(PROCESSED_DIR, 'X_val.npy'))
    y_val = np.load(os.path.join(PROCESSED_DIR, 'y_val.npy'))
    X_test = np.load(os.path.join(PROCESSED_DIR, 'X_test.npy'))
    y_test = np.load(os.path.join(PROCESSED_DIR, 'y_test.npy'))
    with open(os.path.join(PROCESSED_DIR, 'class_names.json'), 'r') as f:
        class_names = json.load(f)
    print("Data loaded successfully.")
except FileNotFoundError:
    print(f"ERROR: Data not found at {PROCESSED_DIR}.")
    exit()

# --- 3. Model Definition and Training ---

# --- Data Augmentation Layer ---
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2)
], name="data_augmentation")

# --- Base Model ---
base_model = MobileNetV3Large(input_shape=(INPUT_SIZE, INPUT_SIZE, 3), include_top=False, weights='imagenet')

# --- STAGE 1: STABLE FEATURE EXTRACTION ---
print("\n--- STAGE 1: STABLE FEATURE EXTRACTION ---")
base_model.trainable = False

inputs = layers.Input(shape=(INPUT_SIZE, INPUT_SIZE, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(len(class_names), activation='softmax')(x)
model = models.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=INITIAL_LR),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Training the classification head...")
history = model.fit(
    X_train, y_train,
    epochs=FEATURE_EXTRACTION_EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_val, y_val),
    callbacks=[EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True, verbose=1)]
)

# --- STAGE 2: ADVANCED FINE-TUNING ---
print("\n--- STAGE 2: ADVANCED FINE-TUNING ---")

# --- Calculate Class Weights (introduced only in Stage 2) ---
print("\nCalculating class weights for fine-tuning...")
class_labels = np.unique(y_train)
weights = class_weight.compute_class_weight('balanced', classes=class_labels, y=y_train)
class_weights_dict = dict(zip(class_labels, weights))
print("Class Weights:", class_weights_dict)

# --- Unfreeze layers for fine-tuning ---
base_model.trainable = True
fine_tune_at = math.ceil(len(base_model.layers) * 0.5) # Unfreeze top 50%
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False
print(f"Unfreezing from layer {fine_tune_at} onwards.")

# --- Re-compile with a very low learning rate ---
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# --- Callbacks for the fine-tuning stage ---
checkpoint_path = os.path.join(model_results_dir, 'best_model.keras')
callbacks_finetune = [
    EarlyStopping(monitor='val_loss', patience=PATIENCE + 5, verbose=1),
    ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1, min_lr=1e-7)
]

print("Fine-tuning the model with class weights and a low learning rate...")
total_epochs = history.epoch[-1] + 1 + FINE_TUNE_EPOCHS
history_fine_tune = model.fit(
    X_train, y_train,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1] + 1,
    batch_size=BATCH_SIZE,
    validation_data=(X_val, y_val),
    class_weight=class_weights_dict, # Introduce class weights here
    callbacks=callbacks_finetune
)

# Load the best model saved during fine-tuning
model = tf.keras.models.load_model(checkpoint_path)

# --- 4. Evaluation and Saving ---
print(f"\n--- {MODEL_NAME} Final Test Set Evaluation ---")
y_pred_test_probs = model.predict(X_test)
y_pred_test_classes = np.argmax(y_pred_test_probs, axis=1)
report_dict = classification_report(y_test, y_pred_test_classes, target_names=class_names, output_dict=True)
print("\nTest Set Classification Report:\n")
print(classification_report(y_test, y_pred_test_classes, target_names=class_names))

# (The rest of the saving and summary code is the same)
report_df = pd.DataFrame(report_dict).transpose()
report_df.to_csv(os.path.join(model_results_dir, 'classification_report.csv'))

cm = confusion_matrix(y_test, y_pred_test_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title(f'{MODEL_NAME} Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.savefig(os.path.join(model_results_dir, 'confusion_matrix.png'))
plt.close()

print("\nUpdating summary results file...")
summary_file = os.path.join(RESULTS_DIR, 'summary_results.csv')
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
summary_data = {
    'model_name': MODEL_NAME,
    'batch_size': BATCH_SIZE,
    'test_accuracy': f"{test_accuracy:.4f}",
    'test_loss': f"{test_loss:.4f}",
    'macro_avg_f1-score': f"{report_dict['macro avg']['f1-score']:.4f}",
    'weighted_avg_f1-score': f"{report_dict['weighted avg']['f1-score']:.4f}"
}
new_results_df = pd.DataFrame([summary_data])
if os.path.exists(summary_file):
    summary_df = pd.read_csv(summary_file)
    if MODEL_NAME in summary_df['model_name'].values:
        summary_df.loc[summary_df['model_name'] == MODEL_NAME] = new_results_df.iloc[0].values
    else:
        summary_df = pd.concat([summary_df, new_results_df], ignore_index=True)
    summary_df.to_csv(summary_file, index=False)
else:
    new_results_df.to_csv(summary_file, index=False)

print(f"\n--- Experiment for {MODEL_NAME} is complete. Best model saved to {checkpoint_path} ---")
# Out:
# ================================================================================
# --- Starting Ultimate Experiment for: MobileNetV3Large_ultimate_finetune_bs8 ---
# Strategy: Hybrid Training with Class Weights, Augmentation, and Fine-Tuning
# ================================================================================
#
# Loading preprocessed data from 'processed_data\BrinjalFruitX_balanced'...
# Data loaded successfully.
#
# --- STAGE 1: STABLE FEATURE EXTRACTION ---
# Training the classification head...
# Epoch 1/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 27s 71ms/step - accuracy: 0.2090 - loss: 1.7872 - val_accuracy: 0.2762 - val_loss: 1.6015
# Epoch 2/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 68ms/step - accuracy: 0.2158 - loss: 1.7212 - val_accuracy: 0.4586 - val_loss: 1.5910
# Epoch 3/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2153 - loss: 1.7093 - val_accuracy: 0.3978 - val_loss: 1.6012
# Epoch 4/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.2075 - loss: 1.6786 - val_accuracy: 0.4696 - val_loss: 1.5897
# Epoch 5/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2044 - loss: 1.6599 - val_accuracy: 0.4917 - val_loss: 1.5944
# Epoch 6/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.1924 - loss: 1.6555 - val_accuracy: 0.4033 - val_loss: 1.5856
# Epoch 7/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2036 - loss: 1.6296 - val_accuracy: 0.3923 - val_loss: 1.5959
# Epoch 8/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2123 - loss: 1.6418 - val_accuracy: 0.3370 - val_loss: 1.6002
# Epoch 9/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2007 - loss: 1.6373 - val_accuracy: 0.1436 - val_loss: 1.6111
# Epoch 10/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2065 - loss: 1.6287 - val_accuracy: 0.4530 - val_loss: 1.5892
# Epoch 11/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 65ms/step - accuracy: 0.1971 - loss: 1.6300 - val_accuracy: 0.4420 - val_loss: 1.5863
# Epoch 12/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 65ms/step - accuracy: 0.2068 - loss: 1.6201 - val_accuracy: 0.2707 - val_loss: 1.6057
# Epoch 13/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 65ms/step - accuracy: 0.2281 - loss: 1.6053 - val_accuracy: 0.4475 - val_loss: 1.5885
# Epoch 14/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 65ms/step - accuracy: 0.2160 - loss: 1.6129 - val_accuracy: 0.3425 - val_loss: 1.5963
# Epoch 15/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2059 - loss: 1.6138 - val_accuracy: 0.1657 - val_loss: 1.5964
# Epoch 16/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 65ms/step - accuracy: 0.2045 - loss: 1.6162 - val_accuracy: 0.4144 - val_loss: 1.5829
# Epoch 17/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.1949 - loss: 1.6142 - val_accuracy: 0.4475 - val_loss: 1.5737
# Epoch 18/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2098 - loss: 1.6109 - val_accuracy: 0.4144 - val_loss: 1.5809
# Epoch 19/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 65ms/step - accuracy: 0.2476 - loss: 1.6000 - val_accuracy: 0.4641 - val_loss: 1.5733
# Epoch 20/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2178 - loss: 1.6105 - val_accuracy: 0.3812 - val_loss: 1.5881
# Epoch 21/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2301 - loss: 1.6001 - val_accuracy: 0.3591 - val_loss: 1.5810
# Epoch 22/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.2217 - loss: 1.6038 - val_accuracy: 0.4420 - val_loss: 1.5751
# Epoch 23/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2047 - loss: 1.6111 - val_accuracy: 0.3867 - val_loss: 1.5747
# Epoch 24/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2440 - loss: 1.5968 - val_accuracy: 0.4088 - val_loss: 1.5703
# Epoch 25/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2299 - loss: 1.6030 - val_accuracy: 0.3702 - val_loss: 1.5790
# Epoch 26/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2059 - loss: 1.6027 - val_accuracy: 0.4807 - val_loss: 1.5569
# Epoch 27/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2540 - loss: 1.6002 - val_accuracy: 0.4088 - val_loss: 1.5693
# Epoch 28/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.2524 - loss: 1.5996 - val_accuracy: 0.3923 - val_loss: 1.5804
# Epoch 29/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2283 - loss: 1.5979 - val_accuracy: 0.3923 - val_loss: 1.5698
# Epoch 30/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.2422 - loss: 1.5959 - val_accuracy: 0.3867 - val_loss: 1.5722
# Epoch 31/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2463 - loss: 1.5930 - val_accuracy: 0.4254 - val_loss: 1.5646
# Epoch 32/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2453 - loss: 1.5956 - val_accuracy: 0.4199 - val_loss: 1.5622
# Epoch 33/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2470 - loss: 1.5950 - val_accuracy: 0.4586 - val_loss: 1.5648
# Epoch 34/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 66ms/step - accuracy: 0.2506 - loss: 1.5927 - val_accuracy: 0.4144 - val_loss: 1.5685
# Epoch 35/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.2555 - loss: 1.5935 - val_accuracy: 0.4254 - val_loss: 1.5565
# Epoch 36/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 68ms/step - accuracy: 0.2388 - loss: 1.5888 - val_accuracy: 0.4254 - val_loss: 1.5629
# Epoch 37/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.2320 - loss: 1.5921 - val_accuracy: 0.4530 - val_loss: 1.5535
# Epoch 38/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.2102 - loss: 1.5989 - val_accuracy: 0.4033 - val_loss: 1.5570
# Epoch 39/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.2469 - loss: 1.5928 - val_accuracy: 0.4365 - val_loss: 1.5554
# Epoch 40/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.2302 - loss: 1.5965 - val_accuracy: 0.4420 - val_loss: 1.5533
# Epoch 41/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 68ms/step - accuracy: 0.2473 - loss: 1.5870 - val_accuracy: 0.4254 - val_loss: 1.5557
# Epoch 42/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 69ms/step - accuracy: 0.2680 - loss: 1.5848 - val_accuracy: 0.4199 - val_loss: 1.5597
# Epoch 43/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 21s 67ms/step - accuracy: 0.2391 - loss: 1.5946 - val_accuracy: 0.3867 - val_loss: 1.5600
# Epoch 44/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 69ms/step - accuracy: 0.2557 - loss: 1.5915 - val_accuracy: 0.3923 - val_loss: 1.5540
# Epoch 45/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 69ms/step - accuracy: 0.2369 - loss: 1.5911 - val_accuracy: 0.4254 - val_loss: 1.5482
# Epoch 46/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 69ms/step - accuracy: 0.2530 - loss: 1.5835 - val_accuracy: 0.4088 - val_loss: 1.5494
# Epoch 47/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 68ms/step - accuracy: 0.2484 - loss: 1.5879 - val_accuracy: 0.4420 - val_loss: 1.5506
# Epoch 48/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 68ms/step - accuracy: 0.2554 - loss: 1.5824 - val_accuracy: 0.4254 - val_loss: 1.5505
# Epoch 49/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 69ms/step - accuracy: 0.2469 - loss: 1.5866 - val_accuracy: 0.4088 - val_loss: 1.5584
# Epoch 50/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 69ms/step - accuracy: 0.2554 - loss: 1.5889 - val_accuracy: 0.4144 - val_loss: 1.5506
# Restoring model weights from the end of the best epoch: 45.
#
# --- STAGE 2: ADVANCED FINE-TUNING ---
#
# Calculating class weights for fine-tuning...
# Class Weights: {np.int32(0): np.float64(1.0), np.int32(1): np.float64(1.0), np.int32(2): np.float64(1.0), np.int32(3): np.float64(1.0), np.int32(4): np.float64(1.0)}
# Unfreezing from layer 94 onwards.
# Fine-tuning the model with class weights and a low learning rate...
# Epoch 51/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.1990 - loss: 2.1950
# Epoch 51: val_loss improved from inf to 1.63101, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 56s 136ms/step - accuracy: 0.1990 - loss: 2.1942 - val_accuracy: 0.1105 - val_loss: 1.6310 - learning_rate: 1.0000e-05
# Epoch 52/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.2323 - loss: 1.7130
# Epoch 52: val_loss did not improve from 1.63101
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.2323 - loss: 1.7129 - val_accuracy: 0.0663 - val_loss: 1.8343 - learning_rate: 1.0000e-05
# Epoch 53/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.2667 - loss: 1.5913
# Epoch 53: val_loss did not improve from 1.63101
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 129ms/step - accuracy: 0.2667 - loss: 1.5913 - val_accuracy: 0.1713 - val_loss: 1.8190 - learning_rate: 1.0000e-05
# Epoch 54/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.3156 - loss: 1.5462
# Epoch 54: val_loss did not improve from 1.63101
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.3156 - loss: 1.5463 - val_accuracy: 0.2762 - val_loss: 1.7457 - learning_rate: 1.0000e-05
# Epoch 55/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.2976 - loss: 1.5472
# Epoch 55: val_loss did not improve from 1.63101
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 129ms/step - accuracy: 0.2976 - loss: 1.5472 - val_accuracy: 0.2873 - val_loss: 1.6790 - learning_rate: 1.0000e-05
# Epoch 56/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.3236 - loss: 1.5239
# Epoch 56: val_loss did not improve from 1.63101
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 129ms/step - accuracy: 0.3236 - loss: 1.5238 - val_accuracy: 0.2928 - val_loss: 1.6821 - learning_rate: 1.0000e-05
# Epoch 57/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.3320 - loss: 1.5229
# Epoch 57: val_loss did not improve from 1.63101
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 42s 132ms/step - accuracy: 0.3320 - loss: 1.5229 - val_accuracy: 0.2597 - val_loss: 1.6722 - learning_rate: 2.0000e-06
# Epoch 58/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.3432 - loss: 1.4873
# Epoch 58: val_loss did not improve from 1.63101
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.3432 - loss: 1.4873 - val_accuracy: 0.2486 - val_loss: 1.6658 - learning_rate: 2.0000e-06
# Epoch 59/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.3208 - loss: 1.5168
# Epoch 59: val_loss did not improve from 1.63101
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.3209 - loss: 1.5167 - val_accuracy: 0.2320 - val_loss: 1.6594 - learning_rate: 2.0000e-06
# Epoch 60/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.3385 - loss: 1.4925
# Epoch 60: val_loss did not improve from 1.63101
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.3384 - loss: 1.4925 - val_accuracy: 0.1547 - val_loss: 1.6752 - learning_rate: 2.0000e-06
# Epoch 61/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.3408 - loss: 1.4732
# Epoch 61: val_loss did not improve from 1.63101
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.3408 - loss: 1.4733 - val_accuracy: 0.1547 - val_loss: 1.7254 - learning_rate: 2.0000e-06
# Epoch 62/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.3555 - loss: 1.4809
# Epoch 62: val_loss did not improve from 1.63101
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.3555 - loss: 1.4809 - val_accuracy: 0.1602 - val_loss: 1.7471 - learning_rate: 4.0000e-07
# Epoch 63/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.3471 - loss: 1.4823
# Epoch 63: val_loss did not improve from 1.63101
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.3470 - loss: 1.4823 - val_accuracy: 0.1934 - val_loss: 1.7290 - learning_rate: 4.0000e-07
# Epoch 64/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.3433 - loss: 1.5006
# Epoch 64: val_loss did not improve from 1.63101
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 129ms/step - accuracy: 0.3434 - loss: 1.5006 - val_accuracy: 0.2099 - val_loss: 1.6862 - learning_rate: 4.0000e-07
# Epoch 65/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.3763 - loss: 1.4668
# Epoch 65: val_loss did not improve from 1.63101
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 129ms/step - accuracy: 0.3763 - loss: 1.4668 - val_accuracy: 0.2320 - val_loss: 1.6346 - learning_rate: 4.0000e-07
# Epoch 66/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.3630 - loss: 1.4772
# Epoch 66: val_loss improved from 1.63101 to 1.57530, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 131ms/step - accuracy: 0.3630 - loss: 1.4772 - val_accuracy: 0.2873 - val_loss: 1.5753 - learning_rate: 4.0000e-07
# Epoch 67/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.3610 - loss: 1.4775
# Epoch 67: val_loss improved from 1.57530 to 1.52331, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.3610 - loss: 1.4775 - val_accuracy: 0.3536 - val_loss: 1.5233 - learning_rate: 4.0000e-07
# Epoch 68/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.3475 - loss: 1.4858
# Epoch 68: val_loss improved from 1.52331 to 1.48789, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.3476 - loss: 1.4857 - val_accuracy: 0.3481 - val_loss: 1.4879 - learning_rate: 4.0000e-07
# Epoch 69/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.3515 - loss: 1.4782
# Epoch 69: val_loss improved from 1.48789 to 1.46031, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 129ms/step - accuracy: 0.3515 - loss: 1.4782 - val_accuracy: 0.3370 - val_loss: 1.4603 - learning_rate: 4.0000e-07
# Epoch 70/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3604 - loss: 1.4748
# Epoch 70: val_loss improved from 1.46031 to 1.43678, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.3604 - loss: 1.4747 - val_accuracy: 0.3757 - val_loss: 1.4368 - learning_rate: 4.0000e-07
# Epoch 71/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3494 - loss: 1.4662
# Epoch 71: val_loss improved from 1.43678 to 1.42227, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.3495 - loss: 1.4662 - val_accuracy: 0.3923 - val_loss: 1.4223 - learning_rate: 4.0000e-07
# Epoch 72/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3482 - loss: 1.4636
# Epoch 72: val_loss improved from 1.42227 to 1.41769, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.3482 - loss: 1.4636 - val_accuracy: 0.3978 - val_loss: 1.4177 - learning_rate: 4.0000e-07
# Epoch 73/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.3545 - loss: 1.4697
# Epoch 73: val_loss improved from 1.41769 to 1.40849, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 38s 119ms/step - accuracy: 0.3545 - loss: 1.4697 - val_accuracy: 0.4365 - val_loss: 1.4085 - learning_rate: 4.0000e-07
# Epoch 74/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3391 - loss: 1.4875
# Epoch 74: val_loss improved from 1.40849 to 1.40255, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.3391 - loss: 1.4875 - val_accuracy: 0.4475 - val_loss: 1.4025 - learning_rate: 4.0000e-07
# Epoch 75/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.3549 - loss: 1.4774
# Epoch 75: val_loss did not improve from 1.40255
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 37s 118ms/step - accuracy: 0.3549 - loss: 1.4773 - val_accuracy: 0.4420 - val_loss: 1.4026 - learning_rate: 4.0000e-07
# Epoch 76/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3448 - loss: 1.4697
# Epoch 76: val_loss improved from 1.40255 to 1.40199, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.3448 - loss: 1.4697 - val_accuracy: 0.4475 - val_loss: 1.4020 - learning_rate: 4.0000e-07
# Epoch 77/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.3593 - loss: 1.4656
# Epoch 77: val_loss improved from 1.40199 to 1.39873, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.3593 - loss: 1.4656 - val_accuracy: 0.4530 - val_loss: 1.3987 - learning_rate: 4.0000e-07
# Epoch 78/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3466 - loss: 1.4781
# Epoch 78: val_loss improved from 1.39873 to 1.39743, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.3467 - loss: 1.4780 - val_accuracy: 0.4530 - val_loss: 1.3974 - learning_rate: 4.0000e-07
# Epoch 79/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3587 - loss: 1.4685
# Epoch 79: val_loss improved from 1.39743 to 1.39659, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.3587 - loss: 1.4685 - val_accuracy: 0.4475 - val_loss: 1.3966 - learning_rate: 4.0000e-07
# Epoch 80/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3377 - loss: 1.4928
# Epoch 80: val_loss improved from 1.39659 to 1.39549, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.3378 - loss: 1.4928 - val_accuracy: 0.4586 - val_loss: 1.3955 - learning_rate: 4.0000e-07
# Epoch 81/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3543 - loss: 1.4764
# Epoch 81: val_loss did not improve from 1.39549
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 125ms/step - accuracy: 0.3543 - loss: 1.4764 - val_accuracy: 0.4530 - val_loss: 1.3963 - learning_rate: 4.0000e-07
# Epoch 82/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3294 - loss: 1.4809
# Epoch 82: val_loss improved from 1.39549 to 1.39264, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.3294 - loss: 1.4809 - val_accuracy: 0.4530 - val_loss: 1.3926 - learning_rate: 4.0000e-07
# Epoch 83/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3557 - loss: 1.4590
# Epoch 83: val_loss improved from 1.39264 to 1.38958, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.3557 - loss: 1.4591 - val_accuracy: 0.4641 - val_loss: 1.3896 - learning_rate: 4.0000e-07
# Epoch 84/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3788 - loss: 1.4444
# Epoch 84: val_loss did not improve from 1.38958
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 125ms/step - accuracy: 0.3788 - loss: 1.4444 - val_accuracy: 0.4475 - val_loss: 1.3907 - learning_rate: 4.0000e-07
# Epoch 85/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.3519 - loss: 1.4698
# Epoch 85: val_loss improved from 1.38958 to 1.38799, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 125ms/step - accuracy: 0.3519 - loss: 1.4697 - val_accuracy: 0.4586 - val_loss: 1.3880 - learning_rate: 4.0000e-07
# Epoch 86/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3754 - loss: 1.4686
# Epoch 86: val_loss improved from 1.38799 to 1.38773, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.3753 - loss: 1.4686 - val_accuracy: 0.4586 - val_loss: 1.3877 - learning_rate: 4.0000e-07
# Epoch 87/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3823 - loss: 1.4664
# Epoch 87: val_loss did not improve from 1.38773
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 125ms/step - accuracy: 0.3822 - loss: 1.4665 - val_accuracy: 0.4530 - val_loss: 1.3885 - learning_rate: 4.0000e-07
# Epoch 88/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3607 - loss: 1.4476
# Epoch 88: val_loss did not improve from 1.38773
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 125ms/step - accuracy: 0.3606 - loss: 1.4476 - val_accuracy: 0.4586 - val_loss: 1.3905 - learning_rate: 4.0000e-07
# Epoch 89/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3484 - loss: 1.4592
# Epoch 89: val_loss improved from 1.38773 to 1.38747, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.3485 - loss: 1.4591 - val_accuracy: 0.4586 - val_loss: 1.3875 - learning_rate: 4.0000e-07
# Epoch 90/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.3563 - loss: 1.4747
# Epoch 90: val_loss did not improve from 1.38747
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.3563 - loss: 1.4747 - val_accuracy: 0.4586 - val_loss: 1.3894 - learning_rate: 4.0000e-07
# Epoch 91/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3595 - loss: 1.4523
# Epoch 91: val_loss did not improve from 1.38747
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.3595 - loss: 1.4523 - val_accuracy: 0.4530 - val_loss: 1.3890 - learning_rate: 4.0000e-07
# Epoch 92/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.3340 - loss: 1.4886
# Epoch 92: val_loss did not improve from 1.38747
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 42s 132ms/step - accuracy: 0.3341 - loss: 1.4886 - val_accuracy: 0.4365 - val_loss: 1.3919 - learning_rate: 4.0000e-07
# Epoch 93/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.3775 - loss: 1.4445
# Epoch 93: val_loss did not improve from 1.38747
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 130ms/step - accuracy: 0.3775 - loss: 1.4446 - val_accuracy: 0.4420 - val_loss: 1.3880 - learning_rate: 4.0000e-07
# Epoch 94/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3594 - loss: 1.4759
# Epoch 94: val_loss did not improve from 1.38747
#
# Epoch 94: ReduceLROnPlateau reducing learning rate to 1e-07.
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 125ms/step - accuracy: 0.3594 - loss: 1.4759 - val_accuracy: 0.4365 - val_loss: 1.3901 - learning_rate: 4.0000e-07
# Epoch 95/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3707 - loss: 1.4419
# Epoch 95: val_loss did not improve from 1.38747
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.3706 - loss: 1.4419 - val_accuracy: 0.4475 - val_loss: 1.3879 - learning_rate: 1.0000e-07
# Epoch 96/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.3665 - loss: 1.4624
# Epoch 96: val_loss improved from 1.38747 to 1.38608, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.3665 - loss: 1.4624 - val_accuracy: 0.4530 - val_loss: 1.3861 - learning_rate: 1.0000e-07
# Epoch 97/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.3603 - loss: 1.4675
# Epoch 97: val_loss improved from 1.38608 to 1.38485, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 129ms/step - accuracy: 0.3603 - loss: 1.4674 - val_accuracy: 0.4586 - val_loss: 1.3849 - learning_rate: 1.0000e-07
# Epoch 98/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.3598 - loss: 1.4620
# Epoch 98: val_loss did not improve from 1.38485
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 127ms/step - accuracy: 0.3598 - loss: 1.4620 - val_accuracy: 0.4586 - val_loss: 1.3850 - learning_rate: 1.0000e-07
# Epoch 99/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3768 - loss: 1.4466
# Epoch 99: val_loss improved from 1.38485 to 1.38340, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.3768 - loss: 1.4466 - val_accuracy: 0.4641 - val_loss: 1.3834 - learning_rate: 1.0000e-07
# Epoch 100/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3968 - loss: 1.4361
# Epoch 100: val_loss improved from 1.38340 to 1.38294, saving model to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 128ms/step - accuracy: 0.3967 - loss: 1.4361 - val_accuracy: 0.4586 - val_loss: 1.3829 - learning_rate: 1.0000e-07
#
# --- MobileNetV3Large_ultimate_finetune_bs8 Final Test Set Evaluation ---
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 231ms/step
#
# Test Set Classification Report:
#
#                         precision    recall  f1-score   support
#
# Brinjal Fruit Creaking       0.31      0.50      0.38        40
#         Healty Brinjal       0.71      0.41      0.52       103
#       Phomopsis Bright       0.22      0.19      0.20        32
#  Shoot and Fruit Borer       0.70      0.61      0.65       145
#                Wet Rot       0.31      0.63      0.42        41
#
#               accuracy                           0.51       361
#              macro avg       0.45      0.47      0.44       361
#           weighted avg       0.57      0.51      0.52       361
#
#
# Updating summary results file...
#
# --- Experiment for MobileNetV3Large_ultimate_finetune_bs8 is complete. Best model saved to results\MobileNetV3Large_ultimate_finetune_bs8\best_model.keras ---

# %%
import os
import numpy as np
import json
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.applications import MobileNetV3Large
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import math
from sklearn.utils import class_weight

# --- 1. Configuration for this Experiment ---
MODEL_CHOICE = "MobileNetV3Large"
INPUT_SIZE = 224
BATCH_SIZE = 8  # Best performing batch size for MobileNet family
INITIAL_LR = 1e-4  # A stable learning rate for the initial stage
FINE_TUNE_LR = 1e-5 # A very low learning rate for the fine-tuning stage
FEATURE_EXTRACTION_EPOCHS = 50
FINE_TUNE_EPOCHS = 50
PATIENCE = 15 # Increased patience for more stable training
RESULTS_DIR = 'results'
MODEL_NAME = f'{MODEL_CHOICE}_ultimate_finetune_bs{BATCH_SIZE}_3'
model_results_dir = os.path.join(RESULTS_DIR, MODEL_NAME)
os.makedirs(model_results_dir, exist_ok=True)

print("="*80)
print(f"--- Starting Ultimate Experiment for: {MODEL_NAME} ---")
print("Strategy: Hybrid Training with Class Weights, Augmentation, and Fine-Tuning")
print("="*80)

# --- 2. Data Loading ---
PROCESSED_DIR = os.path.join('processed_data', 'BrinjalFruitX_balanced_classless')
print(f"\nLoading preprocessed data from '{PROCESSED_DIR}'...")
try:
    X_train = np.load(os.path.join(PROCESSED_DIR, 'X_train.npy'))
    y_train = np.load(os.path.join(PROCESSED_DIR, 'y_train.npy'))
    X_val = np.load(os.path.join(PROCESSED_DIR, 'X_val.npy'))
    y_val = np.load(os.path.join(PROCESSED_DIR, 'y_val.npy'))
    X_test = np.load(os.path.join(PROCESSED_DIR, 'X_test.npy'))
    y_test = np.load(os.path.join(PROCESSED_DIR, 'y_test.npy'))
    with open(os.path.join(PROCESSED_DIR, 'class_names.json'), 'r') as f:
        class_names = json.load(f)
    print("Data loaded successfully.")
except FileNotFoundError:
    print(f"ERROR: Data not found at {PROCESSED_DIR}.")
    exit()

# --- 3. Model Definition and Training ---

# --- Data Augmentation Layer ---
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2)
], name="data_augmentation")

# --- Base Model ---
base_model = MobileNetV3Large(input_shape=(INPUT_SIZE, INPUT_SIZE, 3), include_top=False, weights='imagenet')

# --- STAGE 1: STABLE FEATURE EXTRACTION ---
print("\n--- STAGE 1: STABLE FEATURE EXTRACTION ---")
base_model.trainable = False

inputs = layers.Input(shape=(INPUT_SIZE, INPUT_SIZE, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(len(class_names), activation='softmax')(x)
model = models.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=INITIAL_LR),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Training the classification head...")
history = model.fit(
    X_train, y_train,
    epochs=FEATURE_EXTRACTION_EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_val, y_val),
    callbacks=[EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True, verbose=1)]
)

# --- STAGE 2: ADVANCED FINE-TUNING ---
print("\n--- STAGE 2: ADVANCED FINE-TUNING ---")

# --- Calculate Class Weights (introduced only in Stage 2) ---
print("\nCalculating class weights for fine-tuning...")
class_labels = np.unique(y_train)
weights = class_weight.compute_class_weight('balanced', classes=class_labels, y=y_train)
class_weights_dict = dict(zip(class_labels, weights))
print("Class Weights:", class_weights_dict)

# --- Unfreeze layers for fine-tuning ---
base_model.trainable = True
fine_tune_at = math.ceil(len(base_model.layers) * 0.5) # Unfreeze top 50%
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False
print(f"Unfreezing from layer {fine_tune_at} onwards.")

# --- Re-compile with a very low learning rate ---
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# --- Callbacks for the fine-tuning stage ---
checkpoint_path = os.path.join(model_results_dir, 'best_model.keras')
callbacks_finetune = [
    EarlyStopping(monitor='val_loss', patience=PATIENCE + 5, verbose=1),
    ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1, min_lr=1e-7)
]

print("Fine-tuning the model with class weights and a low learning rate...")
total_epochs = history.epoch[-1] + 1 + FINE_TUNE_EPOCHS
history_fine_tune = model.fit(
    X_train, y_train,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1] + 1,
    batch_size=BATCH_SIZE,
    validation_data=(X_val, y_val),
    class_weight=class_weights_dict, # Introduce class weights here
    callbacks=callbacks_finetune
)

# Load the best model saved during fine-tuning
model = tf.keras.models.load_model(checkpoint_path)

# --- 4. Evaluation and Saving ---
print(f"\n--- {MODEL_NAME} Final Test Set Evaluation ---")
y_pred_test_probs = model.predict(X_test)
y_pred_test_classes = np.argmax(y_pred_test_probs, axis=1)
report_dict = classification_report(y_test, y_pred_test_classes, target_names=class_names, output_dict=True)
print("\nTest Set Classification Report:\n")
print(classification_report(y_test, y_pred_test_classes, target_names=class_names))

# (The rest of the saving and summary code is the same)
report_df = pd.DataFrame(report_dict).transpose()
report_df.to_csv(os.path.join(model_results_dir, 'classification_report.csv'))

cm = confusion_matrix(y_test, y_pred_test_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title(f'{MODEL_NAME} Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.savefig(os.path.join(model_results_dir, 'confusion_matrix.png'))
plt.close()

print("\nUpdating summary results file...")
summary_file = os.path.join(RESULTS_DIR, 'summary_results.csv')
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
summary_data = {
    'model_name': MODEL_NAME,
    'batch_size': BATCH_SIZE,
    'test_accuracy': f"{test_accuracy:.4f}",
    'test_loss': f"{test_loss:.4f}",
    'macro_avg_f1-score': f"{report_dict['macro avg']['f1-score']:.4f}",
    'weighted_avg_f1-score': f"{report_dict['weighted avg']['f1-score']:.4f}"
}
new_results_df = pd.DataFrame([summary_data])
if os.path.exists(summary_file):
    summary_df = pd.read_csv(summary_file)
    if MODEL_NAME in summary_df['model_name'].values:
        summary_df.loc[summary_df['model_name'] == MODEL_NAME] = new_results_df.iloc[0].values
    else:
        summary_df = pd.concat([summary_df, new_results_df], ignore_index=True)
    summary_df.to_csv(summary_file, index=False)
else:
    new_results_df.to_csv(summary_file, index=False)

print(f"\n--- Experiment for {MODEL_NAME} is complete. Best model saved to {checkpoint_path} ---")
# Out:
# ================================================================================
# --- Starting Ultimate Experiment for: MobileNetV3Large_ultimate_finetune_bs8_3 ---
# Strategy: Hybrid Training with Class Weights, Augmentation, and Fine-Tuning
# ================================================================================
#
# Loading preprocessed data from 'processed_data\BrinjalFruitX_balanced_classless'...
# Data loaded successfully.
#
# --- STAGE 1: STABLE FEATURE EXTRACTION ---
# Training the classification head...
# Epoch 1/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 14s 77ms/step - accuracy: 0.4394 - loss: 0.8671 - val_accuracy: 0.5887 - val_loss: 0.6910
# Epoch 2/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.4695 - loss: 0.7680 - val_accuracy: 0.3710 - val_loss: 0.7000
# Epoch 3/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.5018 - loss: 0.7524 - val_accuracy: 0.4113 - val_loss: 0.7120
# Epoch 4/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.5359 - loss: 0.7214 - val_accuracy: 0.4113 - val_loss: 0.7017
# Epoch 5/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - accuracy: 0.4890 - loss: 0.7438 - val_accuracy: 0.4597 - val_loss: 0.6939
# Epoch 6/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.5077 - loss: 0.7250 - val_accuracy: 0.5565 - val_loss: 0.6923
# Epoch 7/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 66ms/step - accuracy: 0.4920 - loss: 0.7195 - val_accuracy: 0.6048 - val_loss: 0.6900
# Epoch 8/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.4867 - loss: 0.7192 - val_accuracy: 0.4839 - val_loss: 0.6925
# Epoch 9/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.5048 - loss: 0.7128 - val_accuracy: 0.6290 - val_loss: 0.6891
# Epoch 10/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.4872 - loss: 0.7175 - val_accuracy: 0.6290 - val_loss: 0.6853
# Epoch 11/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.5303 - loss: 0.7019 - val_accuracy: 0.6694 - val_loss: 0.6850
# Epoch 12/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.5269 - loss: 0.6948 - val_accuracy: 0.7258 - val_loss: 0.6856
# Epoch 13/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.5196 - loss: 0.6979 - val_accuracy: 0.6694 - val_loss: 0.6865
# Epoch 14/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.5213 - loss: 0.6942 - val_accuracy: 0.6694 - val_loss: 0.6807
# Epoch 15/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.5038 - loss: 0.7051 - val_accuracy: 0.6774 - val_loss: 0.6842
# Epoch 16/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.5424 - loss: 0.6872 - val_accuracy: 0.7419 - val_loss: 0.6799
# Epoch 17/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.4939 - loss: 0.7009 - val_accuracy: 0.7419 - val_loss: 0.6794
# Epoch 18/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.5253 - loss: 0.6900 - val_accuracy: 0.7016 - val_loss: 0.6811
# Epoch 19/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.5288 - loss: 0.6873 - val_accuracy: 0.7177 - val_loss: 0.6796
# Epoch 20/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.5813 - loss: 0.6836 - val_accuracy: 0.6935 - val_loss: 0.6797
# Epoch 21/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - accuracy: 0.5470 - loss: 0.6889 - val_accuracy: 0.7500 - val_loss: 0.6729
# Epoch 22/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - accuracy: 0.5353 - loss: 0.6855 - val_accuracy: 0.7419 - val_loss: 0.6757
# Epoch 23/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.5175 - loss: 0.6933 - val_accuracy: 0.7581 - val_loss: 0.6731
# Epoch 24/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - accuracy: 0.5687 - loss: 0.6840 - val_accuracy: 0.6694 - val_loss: 0.6771
# Epoch 25/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.5493 - loss: 0.6875 - val_accuracy: 0.6774 - val_loss: 0.6764
# Epoch 26/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.5441 - loss: 0.6786 - val_accuracy: 0.7581 - val_loss: 0.6697
# Epoch 27/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.5704 - loss: 0.6805 - val_accuracy: 0.7661 - val_loss: 0.6703
# Epoch 28/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.5412 - loss: 0.6896 - val_accuracy: 0.7661 - val_loss: 0.6664
# Epoch 29/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.5310 - loss: 0.6893 - val_accuracy: 0.7500 - val_loss: 0.6673
# Epoch 30/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.5803 - loss: 0.6810 - val_accuracy: 0.7661 - val_loss: 0.6659
# Epoch 31/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.5715 - loss: 0.6810 - val_accuracy: 0.7258 - val_loss: 0.6603
# Epoch 32/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.6023 - loss: 0.6748 - val_accuracy: 0.7500 - val_loss: 0.6647
# Epoch 33/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.6013 - loss: 0.6771 - val_accuracy: 0.7500 - val_loss: 0.6660
# Epoch 34/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.5694 - loss: 0.6791 - val_accuracy: 0.7742 - val_loss: 0.6616
# Epoch 35/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.5776 - loss: 0.6813 - val_accuracy: 0.7581 - val_loss: 0.6589
# Epoch 36/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.5492 - loss: 0.6776 - val_accuracy: 0.7742 - val_loss: 0.6586
# Epoch 37/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.6077 - loss: 0.6699 - val_accuracy: 0.7500 - val_loss: 0.6596
# Epoch 38/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.6235 - loss: 0.6683 - val_accuracy: 0.7581 - val_loss: 0.6549
# Epoch 39/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.5734 - loss: 0.6804 - val_accuracy: 0.7419 - val_loss: 0.6584
# Epoch 40/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.6030 - loss: 0.6701 - val_accuracy: 0.7581 - val_loss: 0.6559
# Epoch 41/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - accuracy: 0.5985 - loss: 0.6767 - val_accuracy: 0.7823 - val_loss: 0.6533
# Epoch 42/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.6194 - loss: 0.6656 - val_accuracy: 0.7742 - val_loss: 0.6521
# Epoch 43/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.6418 - loss: 0.6655 - val_accuracy: 0.7661 - val_loss: 0.6555
# Epoch 44/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.6032 - loss: 0.6687 - val_accuracy: 0.7661 - val_loss: 0.6520
# Epoch 45/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - accuracy: 0.5894 - loss: 0.6781 - val_accuracy: 0.7339 - val_loss: 0.6521
# Epoch 46/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.5806 - loss: 0.6742 - val_accuracy: 0.7742 - val_loss: 0.6502
# Epoch 47/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.6032 - loss: 0.6691 - val_accuracy: 0.7661 - val_loss: 0.6473
# Epoch 48/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.6067 - loss: 0.6679 - val_accuracy: 0.7823 - val_loss: 0.6469
# Epoch 49/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.5890 - loss: 0.6709 - val_accuracy: 0.7581 - val_loss: 0.6524
# Epoch 50/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - accuracy: 0.6277 - loss: 0.6664 - val_accuracy: 0.7661 - val_loss: 0.6497
# Restoring model weights from the end of the best epoch: 48.
#
# --- STAGE 2: ADVANCED FINE-TUNING ---
#
# Calculating class weights for fine-tuning...
# Class Weights: {np.int32(0): np.float64(1.0), np.int32(1): np.float64(1.0)}
# Unfreezing from layer 94 onwards.
# Fine-tuning the model with class weights and a low learning rate...
# Epoch 51/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5221 - loss: 1.0049
# Epoch 51: val_loss improved from inf to 0.65576, saving model to results\MobileNetV3Large_ultimate_finetune_bs8_3\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 30s 145ms/step - accuracy: 0.5221 - loss: 1.0043 - val_accuracy: 0.7258 - val_loss: 0.6558 - learning_rate: 1.0000e-05
# Epoch 52/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6214 - loss: 0.7112
# Epoch 52: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 123ms/step - accuracy: 0.6213 - loss: 0.7112 - val_accuracy: 0.6532 - val_loss: 0.6628 - learning_rate: 1.0000e-05
# Epoch 53/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.6127 - loss: 0.7187
# Epoch 53: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 15s 122ms/step - accuracy: 0.6128 - loss: 0.7185 - val_accuracy: 0.4194 - val_loss: 0.6817 - learning_rate: 1.0000e-05
# Epoch 54/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6621 - loss: 0.6354
# Epoch 54: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 122ms/step - accuracy: 0.6620 - loss: 0.6353 - val_accuracy: 0.4113 - val_loss: 0.7249 - learning_rate: 1.0000e-05
# Epoch 55/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6632 - loss: 0.6440
# Epoch 55: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 122ms/step - accuracy: 0.6632 - loss: 0.6439 - val_accuracy: 0.4113 - val_loss: 0.7782 - learning_rate: 1.0000e-05
# Epoch 56/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6831 - loss: 0.6087
# Epoch 56: val_loss did not improve from 0.65576
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 124ms/step - accuracy: 0.6831 - loss: 0.6088 - val_accuracy: 0.4113 - val_loss: 0.8415 - learning_rate: 1.0000e-05
# Epoch 57/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6658 - loss: 0.6210
# Epoch 57: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 122ms/step - accuracy: 0.6659 - loss: 0.6209 - val_accuracy: 0.4113 - val_loss: 0.9236 - learning_rate: 2.0000e-06
# Epoch 58/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6874 - loss: 0.6199
# Epoch 58: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 122ms/step - accuracy: 0.6875 - loss: 0.6198 - val_accuracy: 0.4113 - val_loss: 1.0430 - learning_rate: 2.0000e-06
# Epoch 59/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.7242 - loss: 0.5612
# Epoch 59: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 17s 132ms/step - accuracy: 0.7240 - loss: 0.5614 - val_accuracy: 0.4113 - val_loss: 1.1286 - learning_rate: 2.0000e-06
# Epoch 60/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6744 - loss: 0.6030
# Epoch 60: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - accuracy: 0.6744 - loss: 0.6030 - val_accuracy: 0.4113 - val_loss: 1.1919 - learning_rate: 2.0000e-06
# Epoch 61/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6547 - loss: 0.6235
# Epoch 61: val_loss did not improve from 0.65576
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.6548 - loss: 0.6234 - val_accuracy: 0.4113 - val_loss: 1.2317 - learning_rate: 2.0000e-06
# Epoch 62/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6742 - loss: 0.6109
# Epoch 62: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - accuracy: 0.6741 - loss: 0.6109 - val_accuracy: 0.4113 - val_loss: 1.2511 - learning_rate: 4.0000e-07
# Epoch 63/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6901 - loss: 0.5944
# Epoch 63: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 129ms/step - accuracy: 0.6903 - loss: 0.5942 - val_accuracy: 0.4113 - val_loss: 1.2489 - learning_rate: 4.0000e-07
# Epoch 64/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7051 - loss: 0.5867
# Epoch 64: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 17s 131ms/step - accuracy: 0.7050 - loss: 0.5868 - val_accuracy: 0.4113 - val_loss: 1.2306 - learning_rate: 4.0000e-07
# Epoch 65/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6928 - loss: 0.5915
# Epoch 65: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - accuracy: 0.6928 - loss: 0.5915 - val_accuracy: 0.4113 - val_loss: 1.2111 - learning_rate: 4.0000e-07
# Epoch 66/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6986 - loss: 0.5604
# Epoch 66: val_loss did not improve from 0.65576
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1e-07.
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.6985 - loss: 0.5605 - val_accuracy: 0.4113 - val_loss: 1.1898 - learning_rate: 4.0000e-07
# Epoch 67/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6750 - loss: 0.5918
# Epoch 67: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.6751 - loss: 0.5916 - val_accuracy: 0.4113 - val_loss: 1.1632 - learning_rate: 1.0000e-07
# Epoch 68/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6616 - loss: 0.5926
# Epoch 68: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.6618 - loss: 0.5925 - val_accuracy: 0.4194 - val_loss: 1.1280 - learning_rate: 1.0000e-07
# Epoch 69/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6829 - loss: 0.5926
# Epoch 69: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.6829 - loss: 0.5927 - val_accuracy: 0.4113 - val_loss: 1.0916 - learning_rate: 1.0000e-07
# Epoch 70/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7175 - loss: 0.5528
# Epoch 70: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.7174 - loss: 0.5530 - val_accuracy: 0.4113 - val_loss: 1.0572 - learning_rate: 1.0000e-07
# Epoch 71/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7241 - loss: 0.5327
# Epoch 71: val_loss did not improve from 0.65576
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 128ms/step - accuracy: 0.7240 - loss: 0.5329 - val_accuracy: 0.4113 - val_loss: 1.0480 - learning_rate: 1.0000e-07
# Epoch 71: early stopping
#
# --- MobileNetV3Large_ultimate_finetune_bs8_3 Final Test Set Evaluation ---
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 275ms/step
#
# Test Set Classification Report:
#
#                        precision    recall  f1-score   support
#
#        Healty Brinjal       0.68      0.66      0.67       103
# Shoot and Fruit Borer       0.76      0.78      0.77       145
#
#              accuracy                           0.73       248
#             macro avg       0.72      0.72      0.72       248
#          weighted avg       0.73      0.73      0.73       248
#
#
# Updating summary results file...
#
# --- Experiment for MobileNetV3Large_ultimate_finetune_bs8_3 is complete. Best model saved to results\MobileNetV3Large_ultimate_finetune_bs8_3\best_model.keras ---

# %%
import os
import numpy as np
import json
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
# --- MODIFIED ---
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import math
from sklearn.utils import class_weight

# --- 1. Configuration for this Experiment ---
# --- MODIFIED ---
MODEL_CHOICE = "MobileNetV2"
INPUT_SIZE = 224
BATCH_SIZE = 8  # Best performing batch size for MobileNet family
INITIAL_LR = 1e-4  # A stable learning rate for the initial stage
FINE_TUNE_LR = 1e-5 # A very low learning rate for the fine-tuning stage
FEATURE_EXTRACTION_EPOCHS = 50
FINE_TUNE_EPOCHS = 50
PATIENCE = 15 # Increased patience for more stable training
RESULTS_DIR = 'results'
MODEL_NAME = f'{MODEL_CHOICE}_ultimate_finetune_bs{BATCH_SIZE}' # --- MODIFIED ---
model_results_dir = os.path.join(RESULTS_DIR, MODEL_NAME)
os.makedirs(model_results_dir, exist_ok=True)

print("="*80)
print(f"--- Starting Ultimate Experiment for: {MODEL_NAME} ---")
print("Strategy: Hybrid Training with Class Weights, Augmentation, and Fine-Tuning")
print("="*80)

# --- 2. Data Loading ---
PROCESSED_DIR = os.path.join('processed_data', 'BrinjalFruitX_balanced_classless')
print(f"\nLoading preprocessed data from '{PROCESSED_DIR}'...")
try:
    X_train = np.load(os.path.join(PROCESSED_DIR, 'X_train.npy'))
    y_train = np.load(os.path.join(PROCESSED_DIR, 'y_train.npy'))
    X_val = np.load(os.path.join(PROCESSED_DIR, 'X_val.npy'))
    y_val = np.load(os.path.join(PROCESSED_DIR, 'y_val.npy'))
    X_test = np.load(os.path.join(PROCESSED_DIR, 'X_test.npy'))
    y_test = np.load(os.path.join(PROCESSED_DIR, 'y_test.npy'))
    with open(os.path.join(PROCESSED_DIR, 'class_names.json'), 'r') as f:
        class_names = json.load(f)
    print("Data loaded successfully.")
except FileNotFoundError:
    print(f"ERROR: Data not found at {PROCESSED_DIR}.")
    exit()

# --- 3. Model Definition and Training ---

# --- Data Augmentation Layer ---
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2)
], name="data_augmentation")

# --- Base Model ---
# --- MODIFIED ---
base_model = MobileNetV2(input_shape=(INPUT_SIZE, INPUT_SIZE, 3), include_top=False, weights='imagenet')

# --- STAGE 1: STABLE FEATURE EXTRACTION ---
print("\n--- STAGE 1: STABLE FEATURE EXTRACTION ---")
base_model.trainable = False

inputs = layers.Input(shape=(INPUT_SIZE, INPUT_SIZE, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(len(class_names), activation='softmax')(x)
model = models.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=INITIAL_LR),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Training the classification head...")
history = model.fit(
    X_train, y_train,
    epochs=FEATURE_EXTRACTION_EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_val, y_val),
    callbacks=[EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True, verbose=1)]
)

# --- STAGE 2: ADVANCED FINE-TUNING ---
print("\n--- STAGE 2: ADVANCED FINE-TUNING ---")

# --- Calculate Class Weights (introduced only in Stage 2) ---
print("\nCalculating class weights for fine-tuning...")
class_labels = np.unique(y_train)
weights = class_weight.compute_class_weight('balanced', classes=class_labels, y=y_train)
class_weights_dict = dict(zip(class_labels, weights))
print("Class Weights:", class_weights_dict)

# --- Unfreeze layers for fine-tuning ---
base_model.trainable = True
fine_tune_at = math.ceil(len(base_model.layers) * 0.5) # Unfreeze top 50%
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False
print(f"Unfreezing from layer {fine_tune_at} onwards.")

# --- Re-compile with a very low learning rate ---
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# --- Callbacks for the fine-tuning stage ---
checkpoint_path = os.path.join(model_results_dir, 'best_model.keras')
callbacks_finetune = [
    EarlyStopping(monitor='val_loss', patience=PATIENCE + 5, verbose=1),
    ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1, min_lr=1e-7)
]

print("Fine-tuning the model with class weights and a low learning rate...")
total_epochs = history.epoch[-1] + 1 + FINE_TUNE_EPOCHS
history_fine_tune = model.fit(
    X_train, y_train,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1] + 1,
    batch_size=BATCH_SIZE,
    validation_data=(X_val, y_val),
    class_weight=class_weights_dict, # Introduce class weights here
    callbacks=callbacks_finetune
)

# Load the best model saved during fine-tuning
model = tf.keras.models.load_model(checkpoint_path)

# --- 4. Evaluation and Saving ---
print(f"\n--- {MODEL_NAME} Final Test Set Evaluation ---")
y_pred_test_probs = model.predict(X_test)
y_pred_test_classes = np.argmax(y_pred_test_probs, axis=1)
report_dict = classification_report(y_test, y_pred_test_classes, target_names=class_names, output_dict=True)
print("\nTest Set Classification Report:\n")
print(classification_report(y_test, y_pred_test_classes, target_names=class_names))

# (The rest of the saving and summary code is the same)
report_df = pd.DataFrame(report_dict).transpose()
report_df.to_csv(os.path.join(model_results_dir, 'classification_report.csv'))

cm = confusion_matrix(y_test, y_pred_test_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title(f'{MODEL_NAME} Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.savefig(os.path.join(model_results_dir, 'confusion_matrix.png'))
plt.close()

print("\nUpdating summary results file...")
summary_file = os.path.join(RESULTS_DIR, 'summary_results.csv')
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
summary_data = {
    'model_name': MODEL_NAME,
    'batch_size': BATCH_SIZE,
    'test_accuracy': f"{test_accuracy:.4f}",
    'test_loss': f"{test_loss:.4f}",
    'macro_avg_f1-score': f"{report_dict['macro avg']['f1-score']:.4f}",
    'weighted_avg_f1-score': f"{report_dict['weighted avg']['f1-score']:.4f}"
}
new_results_df = pd.DataFrame([summary_data])
if os.path.exists(summary_file):
    summary_df = pd.read_csv(summary_file)
    if MODEL_NAME in summary_df['model_name'].values:
        summary_df.loc[summary_df['model_name'] == MODEL_NAME] = new_results_df.iloc[0].values
    else:
        summary_df = pd.concat([summary_df, new_results_df], ignore_index=True)
    summary_df.to_csv(summary_file, index=False)
else:
    new_results_df.to_csv(summary_file, index=False)

print(f"\n--- Experiment for {MODEL_NAME} is complete. Best model saved to {checkpoint_path} ---")
# Out:
# ================================================================================
# --- Starting Ultimate Experiment for: MobileNetV2_ultimate_finetune_bs8 ---
# Strategy: Hybrid Training with Class Weights, Augmentation, and Fine-Tuning
# ================================================================================
#
# Loading preprocessed data from 'processed_data\BrinjalFruitX_balanced_classless'...
# Data loaded successfully.
#
# --- STAGE 1: STABLE FEATURE EXTRACTION ---
# Training the classification head...
# Epoch 1/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 14s 85ms/step - accuracy: 0.5422 - loss: 0.8895 - val_accuracy: 0.6532 - val_loss: 0.6075
# Epoch 2/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.6274 - loss: 0.7075 - val_accuracy: 0.6935 - val_loss: 0.5417
# Epoch 3/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.7126 - loss: 0.5577 - val_accuracy: 0.7258 - val_loss: 0.5027
# Epoch 4/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.7501 - loss: 0.5146 - val_accuracy: 0.7339 - val_loss: 0.4648
# Epoch 5/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.8057 - loss: 0.4536 - val_accuracy: 0.7258 - val_loss: 0.5047
# Epoch 6/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.8076 - loss: 0.4170 - val_accuracy: 0.7500 - val_loss: 0.4295
# Epoch 7/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.8315 - loss: 0.4445 - val_accuracy: 0.7419 - val_loss: 0.4466
# Epoch 8/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.8693 - loss: 0.3303 - val_accuracy: 0.7500 - val_loss: 0.4236
# Epoch 9/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.8519 - loss: 0.3570 - val_accuracy: 0.7742 - val_loss: 0.3888
# Epoch 10/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.8768 - loss: 0.2899 - val_accuracy: 0.7984 - val_loss: 0.3690
# Epoch 11/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.8551 - loss: 0.3001 - val_accuracy: 0.8306 - val_loss: 0.3306
# Epoch 12/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.8902 - loss: 0.2788 - val_accuracy: 0.8226 - val_loss: 0.3451
# Epoch 13/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.8776 - loss: 0.2777 - val_accuracy: 0.8145 - val_loss: 0.3561
# Epoch 14/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - accuracy: 0.8930 - loss: 0.2793 - val_accuracy: 0.8468 - val_loss: 0.3306
# Epoch 15/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.8954 - loss: 0.2649 - val_accuracy: 0.8468 - val_loss: 0.3099
# Epoch 16/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - accuracy: 0.8968 - loss: 0.2450 - val_accuracy: 0.8468 - val_loss: 0.3099
# Epoch 17/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.8871 - loss: 0.2777 - val_accuracy: 0.8468 - val_loss: 0.3015
# Epoch 18/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.8960 - loss: 0.2545 - val_accuracy: 0.8468 - val_loss: 0.3074
# Epoch 19/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.9042 - loss: 0.2335 - val_accuracy: 0.8629 - val_loss: 0.2983
# Epoch 20/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9219 - loss: 0.2070 - val_accuracy: 0.8710 - val_loss: 0.2810
# Epoch 21/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.9074 - loss: 0.2237 - val_accuracy: 0.8710 - val_loss: 0.2779
# Epoch 22/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.9168 - loss: 0.2020 - val_accuracy: 0.8710 - val_loss: 0.2693
# Epoch 23/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.9137 - loss: 0.1972 - val_accuracy: 0.8790 - val_loss: 0.2549
# Epoch 24/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.8957 - loss: 0.2449 - val_accuracy: 0.8871 - val_loss: 0.2735
# Epoch 25/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9087 - loss: 0.2196 - val_accuracy: 0.8952 - val_loss: 0.2542
# Epoch 26/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.9191 - loss: 0.2277 - val_accuracy: 0.9032 - val_loss: 0.2545
# Epoch 27/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.9154 - loss: 0.1897 - val_accuracy: 0.9032 - val_loss: 0.2444
# Epoch 28/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9362 - loss: 0.1824 - val_accuracy: 0.9113 - val_loss: 0.2443
# Epoch 29/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.9265 - loss: 0.1915 - val_accuracy: 0.9113 - val_loss: 0.2196
# Epoch 30/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9270 - loss: 0.1954 - val_accuracy: 0.8952 - val_loss: 0.2572
# Epoch 31/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9308 - loss: 0.1838 - val_accuracy: 0.9032 - val_loss: 0.2553
# Epoch 32/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9425 - loss: 0.1720 - val_accuracy: 0.8952 - val_loss: 0.2612
# Epoch 33/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9124 - loss: 0.2045 - val_accuracy: 0.9113 - val_loss: 0.2520
# Epoch 34/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9234 - loss: 0.2073 - val_accuracy: 0.9194 - val_loss: 0.2338
# Epoch 35/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9396 - loss: 0.1683 - val_accuracy: 0.9274 - val_loss: 0.2192
# Epoch 36/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.9211 - loss: 0.1858 - val_accuracy: 0.9274 - val_loss: 0.2161
# Epoch 37/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9345 - loss: 0.1501 - val_accuracy: 0.9274 - val_loss: 0.2229
# Epoch 38/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9235 - loss: 0.1998 - val_accuracy: 0.9194 - val_loss: 0.2371
# Epoch 39/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9094 - loss: 0.2341 - val_accuracy: 0.9274 - val_loss: 0.2184
# Epoch 40/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9464 - loss: 0.1530 - val_accuracy: 0.9194 - val_loss: 0.2330
# Epoch 41/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9427 - loss: 0.1524 - val_accuracy: 0.9274 - val_loss: 0.2173
# Epoch 42/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.9342 - loss: 0.1571 - val_accuracy: 0.9274 - val_loss: 0.2250
# Epoch 43/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.9464 - loss: 0.1595 - val_accuracy: 0.9274 - val_loss: 0.2206
# Epoch 44/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - accuracy: 0.9416 - loss: 0.1570 - val_accuracy: 0.9194 - val_loss: 0.2301
# Epoch 45/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.9301 - loss: 0.1782 - val_accuracy: 0.9274 - val_loss: 0.2176
# Epoch 46/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 73ms/step - accuracy: 0.9251 - loss: 0.1805 - val_accuracy: 0.9274 - val_loss: 0.2160
# Epoch 47/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - accuracy: 0.9483 - loss: 0.1453 - val_accuracy: 0.9274 - val_loss: 0.2197
# Epoch 48/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - accuracy: 0.9412 - loss: 0.1283 - val_accuracy: 0.9274 - val_loss: 0.2224
# Epoch 49/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - accuracy: 0.9464 - loss: 0.1436 - val_accuracy: 0.9274 - val_loss: 0.2097
# Epoch 50/50
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 9s 74ms/step - accuracy: 0.9338 - loss: 0.1576 - val_accuracy: 0.9274 - val_loss: 0.2187
# Restoring model weights from the end of the best epoch: 49.
#
# --- STAGE 2: ADVANCED FINE-TUNING ---
#
# Calculating class weights for fine-tuning...
# Class Weights: {np.int32(0): np.float64(1.0), np.int32(1): np.float64(1.0)}
# Unfreezing from layer 77 onwards.
# Fine-tuning the model with class weights and a low learning rate...
# Epoch 51/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.8051 - loss: 0.4979
# Epoch 51: val_loss improved from inf to 0.41575, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 29s 139ms/step - accuracy: 0.8052 - loss: 0.4975 - val_accuracy: 0.8548 - val_loss: 0.4157 - learning_rate: 1.0000e-05
# Epoch 52/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8710 - loss: 0.3092
# Epoch 52: val_loss did not improve from 0.41575
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 123ms/step - accuracy: 0.8710 - loss: 0.3093 - val_accuracy: 0.8226 - val_loss: 0.5178 - learning_rate: 1.0000e-05
# Epoch 53/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9062 - loss: 0.2249
# Epoch 53: val_loss did not improve from 0.41575
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 15s 120ms/step - accuracy: 0.9062 - loss: 0.2249 - val_accuracy: 0.8468 - val_loss: 0.4583 - learning_rate: 1.0000e-05
# Epoch 54/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9010 - loss: 0.3025
# Epoch 54: val_loss did not improve from 0.41575
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 123ms/step - accuracy: 0.9010 - loss: 0.3022 - val_accuracy: 0.8629 - val_loss: 0.4344 - learning_rate: 1.0000e-05
# Epoch 55/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9008 - loss: 0.2423
# Epoch 55: val_loss did not improve from 0.41575
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 15s 121ms/step - accuracy: 0.9008 - loss: 0.2423 - val_accuracy: 0.8548 - val_loss: 0.4338 - learning_rate: 1.0000e-05
# Epoch 56/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9090 - loss: 0.2234
# Epoch 56: val_loss improved from 0.41575 to 0.33209, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 18s 142ms/step - accuracy: 0.9090 - loss: 0.2234 - val_accuracy: 0.8952 - val_loss: 0.3321 - learning_rate: 1.0000e-05
# Epoch 57/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9181 - loss: 0.2082
# Epoch 57: val_loss improved from 0.33209 to 0.26893, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 125ms/step - accuracy: 0.9181 - loss: 0.2083 - val_accuracy: 0.9032 - val_loss: 0.2689 - learning_rate: 1.0000e-05
# Epoch 58/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9080 - loss: 0.2335
# Epoch 58: val_loss improved from 0.26893 to 0.21355, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 125ms/step - accuracy: 0.9080 - loss: 0.2334 - val_accuracy: 0.9274 - val_loss: 0.2136 - learning_rate: 1.0000e-05
# Epoch 59/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9170 - loss: 0.2059
# Epoch 59: val_loss improved from 0.21355 to 0.18635, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.9170 - loss: 0.2059 - val_accuracy: 0.9435 - val_loss: 0.1864 - learning_rate: 1.0000e-05
# Epoch 60/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9476 - loss: 0.1632
# Epoch 60: val_loss did not improve from 0.18635
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 124ms/step - accuracy: 0.9475 - loss: 0.1634 - val_accuracy: 0.9435 - val_loss: 0.2297 - learning_rate: 1.0000e-05
# Epoch 61/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9494 - loss: 0.1305
# Epoch 61: val_loss did not improve from 0.18635
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 123ms/step - accuracy: 0.9494 - loss: 0.1305 - val_accuracy: 0.9516 - val_loss: 0.2107 - learning_rate: 1.0000e-05
# Epoch 62/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9106 - loss: 0.2277
# Epoch 62: val_loss did not improve from 0.18635
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 123ms/step - accuracy: 0.9106 - loss: 0.2276 - val_accuracy: 0.9435 - val_loss: 0.2105 - learning_rate: 1.0000e-05
# Epoch 63/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9409 - loss: 0.1580
# Epoch 63: val_loss improved from 0.18635 to 0.17525, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.9409 - loss: 0.1580 - val_accuracy: 0.9435 - val_loss: 0.1753 - learning_rate: 1.0000e-05
# Epoch 64/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9532 - loss: 0.1087
# Epoch 64: val_loss did not improve from 0.17525
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 124ms/step - accuracy: 0.9532 - loss: 0.1087 - val_accuracy: 0.9435 - val_loss: 0.2177 - learning_rate: 1.0000e-05
# Epoch 65/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9430 - loss: 0.1568
# Epoch 65: val_loss improved from 0.17525 to 0.14632, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.9430 - loss: 0.1569 - val_accuracy: 0.9597 - val_loss: 0.1463 - learning_rate: 1.0000e-05
# Epoch 66/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.9507 - loss: 0.1349
# Epoch 66: val_loss did not improve from 0.14632
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 124ms/step - accuracy: 0.9506 - loss: 0.1350 - val_accuracy: 0.9516 - val_loss: 0.1607 - learning_rate: 1.0000e-05
# Epoch 67/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9593 - loss: 0.1245
# Epoch 67: val_loss did not improve from 0.14632
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9593 - loss: 0.1243 - val_accuracy: 0.9516 - val_loss: 0.1782 - learning_rate: 1.0000e-05
# Epoch 68/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9490 - loss: 0.1378
# Epoch 68: val_loss improved from 0.14632 to 0.13688, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 129ms/step - accuracy: 0.9490 - loss: 0.1377 - val_accuracy: 0.9597 - val_loss: 0.1369 - learning_rate: 1.0000e-05
# Epoch 69/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9454 - loss: 0.1318
# Epoch 69: val_loss did not improve from 0.13688
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 125ms/step - accuracy: 0.9454 - loss: 0.1319 - val_accuracy: 0.9677 - val_loss: 0.1428 - learning_rate: 1.0000e-05
# Epoch 70/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9750 - loss: 0.0789
# Epoch 70: val_loss did not improve from 0.13688
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9749 - loss: 0.0791 - val_accuracy: 0.9516 - val_loss: 0.1557 - learning_rate: 1.0000e-05
# Epoch 71/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9643 - loss: 0.0914
# Epoch 71: val_loss did not improve from 0.13688
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9643 - loss: 0.0917 - val_accuracy: 0.9597 - val_loss: 0.1505 - learning_rate: 1.0000e-05
# Epoch 72/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9466 - loss: 0.1271
# Epoch 72: val_loss did not improve from 0.13688
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9467 - loss: 0.1271 - val_accuracy: 0.9435 - val_loss: 0.1427 - learning_rate: 1.0000e-05
# Epoch 73/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9616 - loss: 0.0992
# Epoch 73: val_loss improved from 0.13688 to 0.09154, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 129ms/step - accuracy: 0.9616 - loss: 0.0994 - val_accuracy: 0.9677 - val_loss: 0.0915 - learning_rate: 1.0000e-05
# Epoch 74/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9456 - loss: 0.1467
# Epoch 74: val_loss did not improve from 0.09154
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9456 - loss: 0.1467 - val_accuracy: 0.9597 - val_loss: 0.1222 - learning_rate: 1.0000e-05
# Epoch 75/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9608 - loss: 0.1117
# Epoch 75: val_loss did not improve from 0.09154
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9607 - loss: 0.1118 - val_accuracy: 0.9274 - val_loss: 0.1829 - learning_rate: 1.0000e-05
# Epoch 76/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9448 - loss: 0.1315
# Epoch 76: val_loss did not improve from 0.09154
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9448 - loss: 0.1314 - val_accuracy: 0.9677 - val_loss: 0.1158 - learning_rate: 1.0000e-05
# Epoch 77/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9582 - loss: 0.0801
# Epoch 77: val_loss improved from 0.09154 to 0.09013, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 129ms/step - accuracy: 0.9582 - loss: 0.0802 - val_accuracy: 0.9758 - val_loss: 0.0901 - learning_rate: 1.0000e-05
# Epoch 78/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9645 - loss: 0.1105
# Epoch 78: val_loss did not improve from 0.09013
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.9645 - loss: 0.1105 - val_accuracy: 0.9677 - val_loss: 0.1040 - learning_rate: 1.0000e-05
# Epoch 79/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9643 - loss: 0.0957
# Epoch 79: val_loss did not improve from 0.09013
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9642 - loss: 0.0959 - val_accuracy: 0.9677 - val_loss: 0.0937 - learning_rate: 1.0000e-05
# Epoch 80/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9664 - loss: 0.0796
# Epoch 80: val_loss improved from 0.09013 to 0.07551, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 129ms/step - accuracy: 0.9664 - loss: 0.0797 - val_accuracy: 0.9758 - val_loss: 0.0755 - learning_rate: 1.0000e-05
# Epoch 81/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9577 - loss: 0.1047
# Epoch 81: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 125ms/step - accuracy: 0.9577 - loss: 0.1047 - val_accuracy: 0.9758 - val_loss: 0.0911 - learning_rate: 1.0000e-05
# Epoch 82/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9700 - loss: 0.0949
# Epoch 82: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9699 - loss: 0.0950 - val_accuracy: 0.9677 - val_loss: 0.1069 - learning_rate: 1.0000e-05
# Epoch 83/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9770 - loss: 0.0651
# Epoch 83: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9770 - loss: 0.0652 - val_accuracy: 0.9677 - val_loss: 0.1108 - learning_rate: 1.0000e-05
# Epoch 84/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9670 - loss: 0.0890
# Epoch 84: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9670 - loss: 0.0891 - val_accuracy: 0.9677 - val_loss: 0.1184 - learning_rate: 1.0000e-05
# Epoch 85/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9615 - loss: 0.0899
# Epoch 85: val_loss did not improve from 0.07551
#
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9615 - loss: 0.0900 - val_accuracy: 0.9677 - val_loss: 0.1204 - learning_rate: 1.0000e-05
# Epoch 86/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9726 - loss: 0.0708
# Epoch 86: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.9726 - loss: 0.0709 - val_accuracy: 0.9677 - val_loss: 0.1118 - learning_rate: 2.0000e-06
# Epoch 87/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9745 - loss: 0.0616
# Epoch 87: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9745 - loss: 0.0616 - val_accuracy: 0.9677 - val_loss: 0.1020 - learning_rate: 2.0000e-06
# Epoch 88/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9867 - loss: 0.0516
# Epoch 88: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9866 - loss: 0.0516 - val_accuracy: 0.9677 - val_loss: 0.0973 - learning_rate: 2.0000e-06
# Epoch 89/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9835 - loss: 0.0462
# Epoch 89: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9835 - loss: 0.0463 - val_accuracy: 0.9677 - val_loss: 0.0974 - learning_rate: 2.0000e-06
# Epoch 90/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9786 - loss: 0.0676
# Epoch 90: val_loss did not improve from 0.07551
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9785 - loss: 0.0677 - val_accuracy: 0.9677 - val_loss: 0.1024 - learning_rate: 2.0000e-06
# Epoch 91/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9527 - loss: 0.1290
# Epoch 91: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9527 - loss: 0.1289 - val_accuracy: 0.9677 - val_loss: 0.1010 - learning_rate: 4.0000e-07
# Epoch 92/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9852 - loss: 0.0542
# Epoch 92: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9852 - loss: 0.0542 - val_accuracy: 0.9677 - val_loss: 0.1015 - learning_rate: 4.0000e-07
# Epoch 93/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9707 - loss: 0.0971
# Epoch 93: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.9707 - loss: 0.0972 - val_accuracy: 0.9597 - val_loss: 0.1006 - learning_rate: 4.0000e-07
# Epoch 94/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9860 - loss: 0.0441
# Epoch 94: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9860 - loss: 0.0442 - val_accuracy: 0.9597 - val_loss: 0.1000 - learning_rate: 4.0000e-07
# Epoch 95/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9805 - loss: 0.0632
# Epoch 95: val_loss did not improve from 0.07551
#
# Epoch 95: ReduceLROnPlateau reducing learning rate to 1e-07.
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9804 - loss: 0.0634 - val_accuracy: 0.9597 - val_loss: 0.1011 - learning_rate: 4.0000e-07
# Epoch 96/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9643 - loss: 0.0863
# Epoch 96: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.9644 - loss: 0.0862 - val_accuracy: 0.9597 - val_loss: 0.1010 - learning_rate: 1.0000e-07
# Epoch 97/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9856 - loss: 0.0456
# Epoch 97: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9856 - loss: 0.0457 - val_accuracy: 0.9516 - val_loss: 0.1005 - learning_rate: 1.0000e-07
# Epoch 98/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9816 - loss: 0.0638
# Epoch 98: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.9816 - loss: 0.0638 - val_accuracy: 0.9516 - val_loss: 0.1013 - learning_rate: 1.0000e-07
# Epoch 99/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9697 - loss: 0.0928
# Epoch 99: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - accuracy: 0.9697 - loss: 0.0927 - val_accuracy: 0.9516 - val_loss: 0.1011 - learning_rate: 1.0000e-07
# Epoch 100/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9776 - loss: 0.0575
# Epoch 100: val_loss did not improve from 0.07551
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 16s 127ms/step - accuracy: 0.9775 - loss: 0.0576 - val_accuracy: 0.9516 - val_loss: 0.1014 - learning_rate: 1.0000e-07
# Epoch 100: early stopping
#
# --- MobileNetV2_ultimate_finetune_bs8 Final Test Set Evaluation ---
# WARNING:tensorflow:5 out of the last 21 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001F499718E00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 261ms/step
#
# Test Set Classification Report:
#
#                        precision    recall  f1-score   support
#
#        Healty Brinjal       0.98      0.96      0.97       103
# Shoot and Fruit Borer       0.97      0.99      0.98       145
#
#              accuracy                           0.98       248
#             macro avg       0.98      0.97      0.98       248
#          weighted avg       0.98      0.98      0.98       248
#
#
# Updating summary results file...
#
# --- Experiment for MobileNetV2_ultimate_finetune_bs8 is complete. Best model saved to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras ---

# %%
import os
import numpy as np
import json
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
# --- MODIFIED ---
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import math
from sklearn.utils import class_weight

# --- 1. Configuration for this Experiment ---
# --- MODIFIED ---
MODEL_CHOICE = "MobileNetV2"
INPUT_SIZE = 224
BATCH_SIZE = 8  # Best performing batch size for MobileNet family
INITIAL_LR = 1e-4  # A stable learning rate for the initial stage
FINE_TUNE_LR = 1e-5 # A very low learning rate for the fine-tuning stage
FEATURE_EXTRACTION_EPOCHS = 50
FINE_TUNE_EPOCHS = 50
PATIENCE = 15 # Increased patience for more stable training
RESULTS_DIR = 'results'
MODEL_NAME = f'{MODEL_CHOICE}_ultimate_finetune_bs{BATCH_SIZE}' # --- MODIFIED ---
model_results_dir = os.path.join(RESULTS_DIR, MODEL_NAME)
os.makedirs(model_results_dir, exist_ok=True)

print("="*80)
print(f"--- Starting Ultimate Experiment for: {MODEL_NAME} ---")
print("Strategy: Hybrid Training with Class Weights, Augmentation, and Fine-Tuning")
print("="*80)

# --- 2. Data Loading ---
PROCESSED_DIR = os.path.join('processed_data', 'BrinjalFruitX_balanced')
print(f"\nLoading preprocessed data from '{PROCESSED_DIR}'...")
try:
    X_train = np.load(os.path.join(PROCESSED_DIR, 'X_train.npy'))
    y_train = np.load(os.path.join(PROCESSED_DIR, 'y_train.npy'))
    X_val = np.load(os.path.join(PROCESSED_DIR, 'X_val.npy'))
    y_val = np.load(os.path.join(PROCESSED_DIR, 'y_val.npy'))
    X_test = np.load(os.path.join(PROCESSED_DIR, 'X_test.npy'))
    y_test = np.load(os.path.join(PROCESSED_DIR, 'y_test.npy'))
    with open(os.path.join(PROCESSED_DIR, 'class_names.json'), 'r') as f:
        class_names = json.load(f)
    print("Data loaded successfully.")
except FileNotFoundError:
    print(f"ERROR: Data not found at {PROCESSED_DIR}.")
    exit()

# --- 3. Model Definition and Training ---

# --- Data Augmentation Layer ---
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2)
], name="data_augmentation")

# --- Base Model ---
# --- MODIFIED ---
base_model = MobileNetV2(input_shape=(INPUT_SIZE, INPUT_SIZE, 3), include_top=False, weights='imagenet')

# --- STAGE 1: STABLE FEATURE EXTRACTION ---
print("\n--- STAGE 1: STABLE FEATURE EXTRACTION ---")
base_model.trainable = False

inputs = layers.Input(shape=(INPUT_SIZE, INPUT_SIZE, 3))
x = data_augmentation(inputs)
x = base_model(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(len(class_names), activation='softmax')(x)
model = models.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=INITIAL_LR),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Training the classification head...")
history = model.fit(
    X_train, y_train,
    epochs=FEATURE_EXTRACTION_EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_val, y_val),
    callbacks=[EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True, verbose=1)]
)

# --- STAGE 2: ADVANCED FINE-TUNING ---
print("\n--- STAGE 2: ADVANCED FINE-TUNING ---")

# --- Calculate Class Weights (introduced only in Stage 2) ---
print("\nCalculating class weights for fine-tuning...")
class_labels = np.unique(y_train)
weights = class_weight.compute_class_weight('balanced', classes=class_labels, y=y_train)
class_weights_dict = dict(zip(class_labels, weights))
print("Class Weights:", class_weights_dict)

# --- Unfreeze layers for fine-tuning ---
base_model.trainable = True
fine_tune_at = math.ceil(len(base_model.layers) * 0.5) # Unfreeze top 50%
for layer in base_model.layers[:fine_tune_at]:
    layer.trainable = False
print(f"Unfreezing from layer {fine_tune_at} onwards.")

# --- Re-compile with a very low learning rate ---
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# --- Callbacks for the fine-tuning stage ---
checkpoint_path = os.path.join(model_results_dir, 'best_model.keras')
callbacks_finetune = [
    EarlyStopping(monitor='val_loss', patience=PATIENCE + 5, verbose=1),
    ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1, min_lr=1e-7)
]

print("Fine-tuning the model with class weights and a low learning rate...")
total_epochs = history.epoch[-1] + 1 + FINE_TUNE_EPOCHS
history_fine_tune = model.fit(
    X_train, y_train,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1] + 1,
    batch_size=BATCH_SIZE,
    validation_data=(X_val, y_val),
    class_weight=class_weights_dict, # Introduce class weights here
    callbacks=callbacks_finetune
)

# Load the best model saved during fine-tuning
model = tf.keras.models.load_model(checkpoint_path)

# --- 4. Evaluation and Saving ---
print(f"\n--- {MODEL_NAME} Final Test Set Evaluation ---")
y_pred_test_probs = model.predict(X_test)
y_pred_test_classes = np.argmax(y_pred_test_probs, axis=1)
report_dict = classification_report(y_test, y_pred_test_classes, target_names=class_names, output_dict=True)
print("\nTest Set Classification Report:\n")
print(classification_report(y_test, y_pred_test_classes, target_names=class_names))

# (The rest of the saving and summary code is the same)
report_df = pd.DataFrame(report_dict).transpose()
report_df.to_csv(os.path.join(model_results_dir, 'classification_report.csv'))

cm = confusion_matrix(y_test, y_pred_test_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title(f'{MODEL_NAME} Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.savefig(os.path.join(model_results_dir, 'confusion_matrix.png'))
plt.close()

print("\nUpdating summary results file...")
summary_file = os.path.join(RESULTS_DIR, 'summary_results.csv')
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
summary_data = {
    'model_name': MODEL_NAME,
    'batch_size': BATCH_SIZE,
    'test_accuracy': f"{test_accuracy:.4f}",
    'test_loss': f"{test_loss:.4f}",
    'macro_avg_f1-score': f"{report_dict['macro avg']['f1-score']:.4f}",
    'weighted_avg_f1-score': f"{report_dict['weighted avg']['f1-score']:.4f}"
}
new_results_df = pd.DataFrame([summary_data])
if os.path.exists(summary_file):
    summary_df = pd.read_csv(summary_file)
    if MODEL_NAME in summary_df['model_name'].values:
        summary_df.loc[summary_df['model_name'] == MODEL_NAME] = new_results_df.iloc[0].values
    else:
        summary_df = pd.concat([summary_df, new_results_df], ignore_index=True)
    summary_df.to_csv(summary_file, index=False)
else:
    new_results_df.to_csv(summary_file, index=False)

print(f"\n--- Experiment for {MODEL_NAME} is complete. Best model saved to {checkpoint_path} ---")
# Out:
# ================================================================================
# --- Starting Ultimate Experiment for: MobileNetV2_ultimate_finetune_bs8 ---
# Strategy: Hybrid Training with Class Weights, Augmentation, and Fine-Tuning
# ================================================================================
#
# Loading preprocessed data from 'processed_data\BrinjalFruitX_balanced'...
# Data loaded successfully.
#
# --- STAGE 1: STABLE FEATURE EXTRACTION ---
# Training the classification head...
# Epoch 1/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 27s 74ms/step - accuracy: 0.2610 - loss: 1.9434 - val_accuracy: 0.5083 - val_loss: 1.2725
# Epoch 2/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - accuracy: 0.4265 - loss: 1.4831 - val_accuracy: 0.6740 - val_loss: 0.9897
# Epoch 3/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 69ms/step - accuracy: 0.5292 - loss: 1.2174 - val_accuracy: 0.7403 - val_loss: 0.8657
# Epoch 4/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - accuracy: 0.5917 - loss: 1.0671 - val_accuracy: 0.7348 - val_loss: 0.7791
# Epoch 5/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 69ms/step - accuracy: 0.6087 - loss: 0.9956 - val_accuracy: 0.7403 - val_loss: 0.7827
# Epoch 6/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - accuracy: 0.6706 - loss: 0.8916 - val_accuracy: 0.7459 - val_loss: 0.7222
# Epoch 7/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 69ms/step - accuracy: 0.6696 - loss: 0.8380 - val_accuracy: 0.7514 - val_loss: 0.6772
# Epoch 8/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 71ms/step - accuracy: 0.6700 - loss: 0.8371 - val_accuracy: 0.7569 - val_loss: 0.6805
# Epoch 9/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - accuracy: 0.6969 - loss: 0.7735 - val_accuracy: 0.7845 - val_loss: 0.6501
# Epoch 10/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - accuracy: 0.7152 - loss: 0.7386 - val_accuracy: 0.7514 - val_loss: 0.6586
# Epoch 11/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 70ms/step - accuracy: 0.7295 - loss: 0.6985 - val_accuracy: 0.7790 - val_loss: 0.6312
# Epoch 12/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - accuracy: 0.7227 - loss: 0.7205 - val_accuracy: 0.7790 - val_loss: 0.6229
# Epoch 13/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - accuracy: 0.7542 - loss: 0.6816 - val_accuracy: 0.7735 - val_loss: 0.6241
# Epoch 14/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - accuracy: 0.7464 - loss: 0.6770 - val_accuracy: 0.7845 - val_loss: 0.5980
# Epoch 15/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - accuracy: 0.7864 - loss: 0.6091 - val_accuracy: 0.7790 - val_loss: 0.5921
# Epoch 16/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - accuracy: 0.7643 - loss: 0.6292 - val_accuracy: 0.7845 - val_loss: 0.5851
# Epoch 17/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - accuracy: 0.7494 - loss: 0.6444 - val_accuracy: 0.8011 - val_loss: 0.5758
# Epoch 18/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 71ms/step - accuracy: 0.7861 - loss: 0.6060 - val_accuracy: 0.7956 - val_loss: 0.5789
# Epoch 19/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 71ms/step - accuracy: 0.7996 - loss: 0.5676 - val_accuracy: 0.8011 - val_loss: 0.5649
# Epoch 20/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 71ms/step - accuracy: 0.7850 - loss: 0.5762 - val_accuracy: 0.7735 - val_loss: 0.5697
# Epoch 21/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.7994 - loss: 0.5203 - val_accuracy: 0.8011 - val_loss: 0.5783
# Epoch 22/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8081 - loss: 0.5147 - val_accuracy: 0.7956 - val_loss: 0.5683
# Epoch 23/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.7977 - loss: 0.5355 - val_accuracy: 0.7956 - val_loss: 0.5680
# Epoch 24/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8115 - loss: 0.5192 - val_accuracy: 0.7901 - val_loss: 0.5502
# Epoch 25/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 71ms/step - accuracy: 0.7999 - loss: 0.5199 - val_accuracy: 0.7735 - val_loss: 0.5558
# Epoch 26/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8017 - loss: 0.5101 - val_accuracy: 0.7956 - val_loss: 0.5605
# Epoch 27/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8227 - loss: 0.4889 - val_accuracy: 0.8011 - val_loss: 0.5400
# Epoch 28/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8212 - loss: 0.4848 - val_accuracy: 0.7956 - val_loss: 0.5597
# Epoch 29/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8104 - loss: 0.5126 - val_accuracy: 0.8066 - val_loss: 0.5708
# Epoch 30/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.7965 - loss: 0.5072 - val_accuracy: 0.7901 - val_loss: 0.5448
# Epoch 31/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8280 - loss: 0.4818 - val_accuracy: 0.7901 - val_loss: 0.5354
# Epoch 32/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8270 - loss: 0.4792 - val_accuracy: 0.7901 - val_loss: 0.5587
# Epoch 33/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8365 - loss: 0.4593 - val_accuracy: 0.7790 - val_loss: 0.5454
# Epoch 34/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.8350 - loss: 0.4532 - val_accuracy: 0.7901 - val_loss: 0.5196
# Epoch 35/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 71ms/step - accuracy: 0.8354 - loss: 0.4546 - val_accuracy: 0.8011 - val_loss: 0.5565
# Epoch 36/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 71ms/step - accuracy: 0.8150 - loss: 0.4919 - val_accuracy: 0.8066 - val_loss: 0.5245
# Epoch 37/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8294 - loss: 0.4449 - val_accuracy: 0.7901 - val_loss: 0.5554
# Epoch 38/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8223 - loss: 0.4796 - val_accuracy: 0.7901 - val_loss: 0.5432
# Epoch 39/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8408 - loss: 0.4325 - val_accuracy: 0.7901 - val_loss: 0.5318
# Epoch 40/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8295 - loss: 0.4658 - val_accuracy: 0.7956 - val_loss: 0.5362
# Epoch 41/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8335 - loss: 0.4408 - val_accuracy: 0.7956 - val_loss: 0.5421
# Epoch 42/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8363 - loss: 0.4379 - val_accuracy: 0.7956 - val_loss: 0.5342
# Epoch 43/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8408 - loss: 0.4134 - val_accuracy: 0.7956 - val_loss: 0.5190
# Epoch 44/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.8468 - loss: 0.4260 - val_accuracy: 0.7790 - val_loss: 0.5260
# Epoch 45/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.8513 - loss: 0.4173 - val_accuracy: 0.7901 - val_loss: 0.5128
# Epoch 46/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8528 - loss: 0.4215 - val_accuracy: 0.8011 - val_loss: 0.5161
# Epoch 47/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8518 - loss: 0.4236 - val_accuracy: 0.7956 - val_loss: 0.5206
# Epoch 48/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8346 - loss: 0.4494 - val_accuracy: 0.7845 - val_loss: 0.5313
# Epoch 49/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 72ms/step - accuracy: 0.8373 - loss: 0.4455 - val_accuracy: 0.8011 - val_loss: 0.5248
# Epoch 50/50
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 23s 73ms/step - accuracy: 0.8413 - loss: 0.4328 - val_accuracy: 0.7956 - val_loss: 0.5293
# Restoring model weights from the end of the best epoch: 45.
#
# --- STAGE 2: ADVANCED FINE-TUNING ---
#
# Calculating class weights for fine-tuning...
# Class Weights: {np.int32(0): np.float64(1.0), np.int32(1): np.float64(1.0), np.int32(2): np.float64(1.0), np.int32(3): np.float64(1.0), np.int32(4): np.float64(1.0)}
# Unfreezing from layer 77 onwards.
# Fine-tuning the model with class weights and a low learning rate...
# Epoch 51/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5820 - loss: 1.2192
# Epoch 51: val_loss improved from inf to 0.76817, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 53s 130ms/step - accuracy: 0.5822 - loss: 1.2185 - val_accuracy: 0.7514 - val_loss: 0.7682 - learning_rate: 1.0000e-05
# Epoch 52/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.7320 - loss: 0.7072
# Epoch 52: val_loss improved from 0.76817 to 0.63272, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 125ms/step - accuracy: 0.7320 - loss: 0.7072 - val_accuracy: 0.7901 - val_loss: 0.6327 - learning_rate: 1.0000e-05
# Epoch 53/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.7523 - loss: 0.6653
# Epoch 53: val_loss improved from 0.63272 to 0.54853, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.7523 - loss: 0.6652 - val_accuracy: 0.8232 - val_loss: 0.5485 - learning_rate: 1.0000e-05
# Epoch 54/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7680 - loss: 0.6216
# Epoch 54: val_loss improved from 0.54853 to 0.46984, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 126ms/step - accuracy: 0.7681 - loss: 0.6216 - val_accuracy: 0.8287 - val_loss: 0.4698 - learning_rate: 1.0000e-05
# Epoch 55/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8246 - loss: 0.4933
# Epoch 55: val_loss did not improve from 0.46984
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 39s 122ms/step - accuracy: 0.8246 - loss: 0.4933 - val_accuracy: 0.8232 - val_loss: 0.4736 - learning_rate: 1.0000e-05
# Epoch 56/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8281 - loss: 0.4670
# Epoch 56: val_loss improved from 0.46984 to 0.46259, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.8281 - loss: 0.4670 - val_accuracy: 0.8398 - val_loss: 0.4626 - learning_rate: 1.0000e-05
# Epoch 57/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8322 - loss: 0.4339
# Epoch 57: val_loss improved from 0.46259 to 0.43987, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.8322 - loss: 0.4338 - val_accuracy: 0.8508 - val_loss: 0.4399 - learning_rate: 1.0000e-05
# Epoch 58/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8485 - loss: 0.4164
# Epoch 58: val_loss improved from 0.43987 to 0.43727, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 125ms/step - accuracy: 0.8484 - loss: 0.4165 - val_accuracy: 0.8398 - val_loss: 0.4373 - learning_rate: 1.0000e-05
# Epoch 59/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8542 - loss: 0.3787
# Epoch 59: val_loss did not improve from 0.43727
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 39s 123ms/step - accuracy: 0.8542 - loss: 0.3786 - val_accuracy: 0.8508 - val_loss: 0.4446 - learning_rate: 1.0000e-05
# Epoch 60/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8750 - loss: 0.3648
# Epoch 60: val_loss improved from 0.43727 to 0.43096, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 125ms/step - accuracy: 0.8750 - loss: 0.3648 - val_accuracy: 0.8564 - val_loss: 0.4310 - learning_rate: 1.0000e-05
# Epoch 61/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8680 - loss: 0.3583
# Epoch 61: val_loss did not improve from 0.43096
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 39s 123ms/step - accuracy: 0.8680 - loss: 0.3582 - val_accuracy: 0.8287 - val_loss: 0.4689 - learning_rate: 1.0000e-05
# Epoch 62/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.8920 - loss: 0.3037
# Epoch 62: val_loss improved from 0.43096 to 0.41785, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.8920 - loss: 0.3037 - val_accuracy: 0.8619 - val_loss: 0.4179 - learning_rate: 1.0000e-05
# Epoch 63/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8965 - loss: 0.2810
# Epoch 63: val_loss improved from 0.41785 to 0.40746, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 125ms/step - accuracy: 0.8965 - loss: 0.2811 - val_accuracy: 0.8729 - val_loss: 0.4075 - learning_rate: 1.0000e-05
# Epoch 64/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8948 - loss: 0.3021
# Epoch 64: val_loss did not improve from 0.40746
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 39s 124ms/step - accuracy: 0.8948 - loss: 0.3021 - val_accuracy: 0.8564 - val_loss: 0.4097 - learning_rate: 1.0000e-05
# Epoch 65/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9021 - loss: 0.2871
# Epoch 65: val_loss improved from 0.40746 to 0.38104, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 40s 125ms/step - accuracy: 0.9021 - loss: 0.2870 - val_accuracy: 0.8619 - val_loss: 0.3810 - learning_rate: 1.0000e-05
# Epoch 66/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9157 - loss: 0.2319
# Epoch 66: val_loss improved from 0.38104 to 0.36165, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.9157 - loss: 0.2319 - val_accuracy: 0.8674 - val_loss: 0.3617 - learning_rate: 1.0000e-05
# Epoch 67/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9156 - loss: 0.2310
# Epoch 67: val_loss did not improve from 0.36165
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 42s 133ms/step - accuracy: 0.9156 - loss: 0.2311 - val_accuracy: 0.8564 - val_loss: 0.3856 - learning_rate: 1.0000e-05
# Epoch 68/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9203 - loss: 0.2129
# Epoch 68: val_loss did not improve from 0.36165
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 42s 133ms/step - accuracy: 0.9203 - loss: 0.2129 - val_accuracy: 0.8674 - val_loss: 0.3864 - learning_rate: 1.0000e-05
# Epoch 69/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9239 - loss: 0.2138
# Epoch 69: val_loss did not improve from 0.36165
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.9239 - loss: 0.2137 - val_accuracy: 0.8619 - val_loss: 0.3876 - learning_rate: 1.0000e-05
# Epoch 70/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9275 - loss: 0.2171
# Epoch 70: val_loss did not improve from 0.36165
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.9275 - loss: 0.2171 - val_accuracy: 0.8785 - val_loss: 0.3637 - learning_rate: 1.0000e-05
# Epoch 71/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9294 - loss: 0.1985
# Epoch 71: val_loss did not improve from 0.36165
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1.9999999494757505e-06.
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.9294 - loss: 0.1985 - val_accuracy: 0.8785 - val_loss: 0.3870 - learning_rate: 1.0000e-05
# Epoch 72/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9360 - loss: 0.1791
# Epoch 72: val_loss did not improve from 0.36165
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 134ms/step - accuracy: 0.9360 - loss: 0.1791 - val_accuracy: 0.8785 - val_loss: 0.3717 - learning_rate: 2.0000e-06
# Epoch 73/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9255 - loss: 0.2069
# Epoch 73: val_loss did not improve from 0.36165
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 134ms/step - accuracy: 0.9255 - loss: 0.2069 - val_accuracy: 0.8785 - val_loss: 0.3667 - learning_rate: 2.0000e-06
# Epoch 74/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9377 - loss: 0.1956
# Epoch 74: val_loss did not improve from 0.36165
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 42s 134ms/step - accuracy: 0.9377 - loss: 0.1955 - val_accuracy: 0.8729 - val_loss: 0.3618 - learning_rate: 2.0000e-06
# Epoch 75/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9280 - loss: 0.1812
# Epoch 75: val_loss improved from 0.36165 to 0.36005, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9280 - loss: 0.1812 - val_accuracy: 0.8729 - val_loss: 0.3600 - learning_rate: 2.0000e-06
# Epoch 76/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9350 - loss: 0.1887
# Epoch 76: val_loss did not improve from 0.36005
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 44s 139ms/step - accuracy: 0.9350 - loss: 0.1887 - val_accuracy: 0.8785 - val_loss: 0.3616 - learning_rate: 2.0000e-06
# Epoch 77/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9405 - loss: 0.1751
# Epoch 77: val_loss did not improve from 0.36005
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9405 - loss: 0.1751 - val_accuracy: 0.8785 - val_loss: 0.3630 - learning_rate: 2.0000e-06
# Epoch 78/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9457 - loss: 0.1797
# Epoch 78: val_loss did not improve from 0.36005
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 135ms/step - accuracy: 0.9457 - loss: 0.1797 - val_accuracy: 0.8729 - val_loss: 0.3612 - learning_rate: 2.0000e-06
# Epoch 79/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9357 - loss: 0.1838
# Epoch 79: val_loss did not improve from 0.36005
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 134ms/step - accuracy: 0.9357 - loss: 0.1838 - val_accuracy: 0.8785 - val_loss: 0.3605 - learning_rate: 2.0000e-06
# Epoch 80/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9304 - loss: 0.1926
# Epoch 80: val_loss improved from 0.36005 to 0.35369, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9304 - loss: 0.1925 - val_accuracy: 0.8785 - val_loss: 0.3537 - learning_rate: 2.0000e-06
# Epoch 81/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9426 - loss: 0.1646
# Epoch 81: val_loss improved from 0.35369 to 0.35198, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9426 - loss: 0.1646 - val_accuracy: 0.8840 - val_loss: 0.3520 - learning_rate: 2.0000e-06
# Epoch 82/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9436 - loss: 0.1540
# Epoch 82: val_loss did not improve from 0.35198
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 135ms/step - accuracy: 0.9436 - loss: 0.1541 - val_accuracy: 0.8840 - val_loss: 0.3521 - learning_rate: 2.0000e-06
# Epoch 83/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9469 - loss: 0.1661
# Epoch 83: val_loss did not improve from 0.35198
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 135ms/step - accuracy: 0.9469 - loss: 0.1661 - val_accuracy: 0.8729 - val_loss: 0.3530 - learning_rate: 2.0000e-06
# Epoch 84/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9394 - loss: 0.1670
# Epoch 84: val_loss improved from 0.35198 to 0.35188, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9395 - loss: 0.1670 - val_accuracy: 0.8840 - val_loss: 0.3519 - learning_rate: 2.0000e-06
# Epoch 85/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9433 - loss: 0.1637
# Epoch 85: val_loss improved from 0.35188 to 0.35107, saving model to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9433 - loss: 0.1637 - val_accuracy: 0.8785 - val_loss: 0.3511 - learning_rate: 2.0000e-06
# Epoch 86/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9394 - loss: 0.1783
# Epoch 86: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 135ms/step - accuracy: 0.9394 - loss: 0.1783 - val_accuracy: 0.8785 - val_loss: 0.3520 - learning_rate: 2.0000e-06
# Epoch 87/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9456 - loss: 0.1635
# Epoch 87: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 135ms/step - accuracy: 0.9456 - loss: 0.1635 - val_accuracy: 0.8785 - val_loss: 0.3572 - learning_rate: 2.0000e-06
# Epoch 88/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.9474 - loss: 0.1546
# Epoch 88: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 134ms/step - accuracy: 0.9474 - loss: 0.1546 - val_accuracy: 0.8895 - val_loss: 0.3532 - learning_rate: 2.0000e-06
# Epoch 89/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9460 - loss: 0.1528
# Epoch 89: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 135ms/step - accuracy: 0.9460 - loss: 0.1528 - val_accuracy: 0.8895 - val_loss: 0.3546 - learning_rate: 2.0000e-06
# Epoch 90/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9474 - loss: 0.1583
# Epoch 90: val_loss did not improve from 0.35107
#
# Epoch 90: ReduceLROnPlateau reducing learning rate to 3.999999989900971e-07.
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9474 - loss: 0.1583 - val_accuracy: 0.8895 - val_loss: 0.3537 - learning_rate: 2.0000e-06
# Epoch 91/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9495 - loss: 0.1551
# Epoch 91: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 44s 138ms/step - accuracy: 0.9495 - loss: 0.1552 - val_accuracy: 0.8895 - val_loss: 0.3558 - learning_rate: 4.0000e-07
# Epoch 92/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9439 - loss: 0.1761
# Epoch 92: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 137ms/step - accuracy: 0.9439 - loss: 0.1760 - val_accuracy: 0.8895 - val_loss: 0.3558 - learning_rate: 4.0000e-07
# Epoch 93/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9443 - loss: 0.1659
# Epoch 93: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9443 - loss: 0.1658 - val_accuracy: 0.8895 - val_loss: 0.3552 - learning_rate: 4.0000e-07
# Epoch 94/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9533 - loss: 0.1432
# Epoch 94: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 135ms/step - accuracy: 0.9533 - loss: 0.1433 - val_accuracy: 0.8895 - val_loss: 0.3547 - learning_rate: 4.0000e-07
# Epoch 95/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9429 - loss: 0.1658
# Epoch 95: val_loss did not improve from 0.35107
#
# Epoch 95: ReduceLROnPlateau reducing learning rate to 1e-07.
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9429 - loss: 0.1657 - val_accuracy: 0.8895 - val_loss: 0.3552 - learning_rate: 4.0000e-07
# Epoch 96/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9537 - loss: 0.1370
# Epoch 96: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 137ms/step - accuracy: 0.9537 - loss: 0.1370 - val_accuracy: 0.8895 - val_loss: 0.3557 - learning_rate: 1.0000e-07
# Epoch 97/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9506 - loss: 0.1391
# Epoch 97: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 137ms/step - accuracy: 0.9506 - loss: 0.1391 - val_accuracy: 0.8895 - val_loss: 0.3562 - learning_rate: 1.0000e-07
# Epoch 98/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9472 - loss: 0.1494
# Epoch 98: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 136ms/step - accuracy: 0.9472 - loss: 0.1494 - val_accuracy: 0.8895 - val_loss: 0.3563 - learning_rate: 1.0000e-07
# Epoch 99/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.9395 - loss: 0.1896
# Epoch 99: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 137ms/step - accuracy: 0.9395 - loss: 0.1895 - val_accuracy: 0.8840 - val_loss: 0.3569 - learning_rate: 1.0000e-07
# Epoch 100/100
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9556 - loss: 0.1378
# Epoch 100: val_loss did not improve from 0.35107
# 317/317 ━━━━━━━━━━━━━━━━━━━━ 43s 137ms/step - accuracy: 0.9556 - loss: 0.1378 - val_accuracy: 0.8840 - val_loss: 0.3570 - learning_rate: 1.0000e-07
#
# --- MobileNetV2_ultimate_finetune_bs8 Final Test Set Evaluation ---
# WARNING:tensorflow:5 out of the last 17 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001F49A4ABF60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 240ms/step
#
# Test Set Classification Report:
#
#                         precision    recall  f1-score   support
#
# Brinjal Fruit Creaking       0.89      0.78      0.83        40
#         Healty Brinjal       0.88      0.98      0.93       103
#       Phomopsis Bright       0.83      0.75      0.79        32
#  Shoot and Fruit Borer       0.93      0.88      0.90       145
#                Wet Rot       0.84      0.90      0.87        41
#
#               accuracy                           0.89       361
#              macro avg       0.87      0.86      0.86       361
#           weighted avg       0.89      0.89      0.89       361
#
#
# Updating summary results file...
#
# --- Experiment for MobileNetV2_ultimate_finetune_bs8 is complete. Best model saved to results\MobileNetV2_ultimate_finetune_bs8\best_model.keras ---
# C:\Users\dr-basab\AppData\Local\Temp\ipykernel_13812\1456964767.py:177: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8892' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   summary_df.loc[summary_df['model_name'] == MODEL_NAME] = new_results_df.iloc[0].values
# C:\Users\dr-basab\AppData\Local\Temp\ipykernel_13812\1456964767.py:177: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.3726' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   summary_df.loc[summary_df['model_name'] == MODEL_NAME] = new_results_df.iloc[0].values
# C:\Users\dr-basab\AppData\Local\Temp\ipykernel_13812\1456964767.py:177: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8631' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   summary_df.loc[summary_df['model_name'] == MODEL_NAME] = new_results_df.iloc[0].values
# C:\Users\dr-basab\AppData\Local\Temp\ipykernel_13812\1456964767.py:177: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.8879' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   summary_df.loc[summary_df['model_name'] == MODEL_NAME] = new_results_df.iloc[0].values

# %% [markdown]
# ---
# ---
# ---
# ---

# %% [markdown]
# exp-2 ends here

# %%
# MobilNetV2 w/o transfer learning

import os
import numpy as np
import json
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
# --- MODIFIED ---
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import math

# --- 1. Configuration for this Experiment ---
# --- MODIFIED ---
MODEL_CHOICE = "MobileNetV2"
INPUT_SIZE = 224
BATCH_SIZE = 8
LEARNING_RATE = 1e-4 # A single, stable learning rate for training from scratch
EPOCHS = 100
PATIENCE = 20 # Increased patience as training from scratch can take longer to converge
RESULTS_DIR = 'results'
MODEL_NAME = f'{MODEL_CHOICE}_from_scratch_bs{BATCH_SIZE}' # --- MODIFIED ---
model_results_dir = os.path.join(RESULTS_DIR, MODEL_NAME)
os.makedirs(model_results_dir, exist_ok=True)

print("="*80)
print(f"--- Starting 'From Scratch' Experiment for: {MODEL_NAME} ---")
print(f"Parameters: Batch Size={BATCH_SIZE}, Learning Rate={LEARNING_RATE}")
print("="*80)

# --- 2. Data Loading ---
# Using the balanced dataset you created
PROCESSED_DIR = os.path.join('processed_data', 'BrinjalFruitX_balanced_classless')
print(f"\nLoading preprocessed data from '{PROCESSED_DIR}'...")
try:
    X_train = np.load(os.path.join(PROCESSED_DIR, 'X_train.npy'))
    y_train = np.load(os.path.join(PROCESSED_DIR, 'y_train.npy'))
    X_val = np.load(os.path.join(PROCESSED_DIR, 'X_val.npy'))
    y_val = np.load(os.path.join(PROCESSED_DIR, 'y_val.npy'))
    X_test = np.load(os.path.join(PROCESSED_DIR, 'X_test.npy'))
    y_test = np.load(os.path.join(PROCESSED_DIR, 'y_test.npy'))
    with open(os.path.join(PROCESSED_DIR, 'class_names.json'), 'r') as f:
        class_names = json.load(f)
    print("Data loaded successfully.")
except FileNotFoundError:
    print(f"ERROR: Data not found at {PROCESSED_DIR}.")
    exit()

# --- 3. Model Definition and Training ---

# --- Data Augmentation Layer ---
data_augmentation = models.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2)
], name="data_augmentation")

# --- Base Model (Training from Scratch) ---
# --- MODIFIED ---
base_model = MobileNetV2(input_shape=(INPUT_SIZE, INPUT_SIZE, 3), include_top=False, weights=None) # No ImageNet weights
base_model.trainable = True # The entire model is trainable

# --- Full Model ---
inputs = layers.Input(shape=(INPUT_SIZE, INPUT_SIZE, 3))
x = data_augmentation(inputs)
x = base_model(x, training=True) # Set training=True as layers are trainable
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(len(class_names), activation='softmax')(x)
model = models.Model(inputs, outputs)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# --- Callbacks for a single training stage ---
checkpoint_path = os.path.join(model_results_dir, 'best_model.keras')
callbacks = [
    EarlyStopping(monitor='val_loss', patience=PATIENCE, verbose=1, restore_best_weights=True),
    ModelCheckpoint(filepath=checkpoint_path, monitor='val_loss', save_best_only=True, verbose=1),
    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, verbose=1, min_lr=1e-7)
]

print("\n--- Starting Single-Stage Training From Scratch ---")
history = model.fit(
    X_train, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_val, y_val),
    callbacks=callbacks
)

# --- 4. Evaluation and Saving ---
print(f"\n--- {MODEL_NAME} Final Test Set Evaluation ---")
y_pred_test_probs = model.predict(X_test)
y_pred_test_classes = np.argmax(y_pred_test_probs, axis=1)
report_dict = classification_report(y_test, y_pred_test_classes, target_names=class_names, output_dict=True)
print("\nTest Set Classification Report:\n")
print(classification_report(y_test, y_pred_test_classes, target_names=class_names))

# (The rest of the saving and summary code is the same)
report_df = pd.DataFrame(report_dict).transpose()
report_df.to_csv(os.path.join(model_results_dir, 'classification_report.csv'))

cm = confusion_matrix(y_test, y_pred_test_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title(f'{MODEL_NAME} Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.savefig(os.path.join(model_results_dir, 'confusion_matrix.png'))
plt.close()

print("\nUpdating summary results file...")
summary_file = os.path.join(RESULTS_DIR, 'summary_results.csv')
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
summary_data = {
    'model_name': MODEL_NAME,
    'batch_size': BATCH_SIZE,
    'test_accuracy': f"{test_accuracy:.4f}",
    'test_loss': f"{test_loss:.4f}",
    'macro_avg_f1-score': f"{report_dict['macro avg']['f1-score']:.4f}",
    'weighted_avg_f1-score': f"{report_dict['weighted avg']['f1-score']:.4f}"
}
new_results_df = pd.DataFrame([summary_data])
if os.path.exists(summary_file):
    summary_df = pd.read_csv(summary_file)
    if MODEL_NAME in summary_df['model_name'].values:
        summary_df.loc[summary_df['model_name'] == MODEL_NAME] = new_results_df.iloc[0].values
    else:
        summary_df = pd.concat([summary_df, new_results_df], ignore_index=True)
    summary_df.to_csv(summary_file, index=False)
else:
    new_results_df.to_csv(summary_file, index=False)

print(f"\n--- Experiment for {MODEL_NAME} is complete. Best model saved to {checkpoint_path} ---")
# Out:
# ================================================================================
# --- Starting 'From Scratch' Experiment for: MobileNetV2_from_scratch_bs8 ---
# Parameters: Batch Size=8, Learning Rate=0.0001
# ================================================================================
#
# Loading preprocessed data from 'processed_data\BrinjalFruitX_balanced_classless'...
# Data loaded successfully.
#
# --- Starting Single-Stage Training From Scratch ---
# Epoch 1/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.5806 - loss: 0.7581
# Epoch 1: val_loss improved from inf to 0.68488, saving model to results\MobileNetV2_from_scratch_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 57s 287ms/step - accuracy: 0.5810 - loss: 0.7576 - val_accuracy: 0.5887 - val_loss: 0.6849 - learning_rate: 1.0000e-04
# Epoch 2/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.6721 - loss: 0.5967
# Epoch 2: val_loss improved from 0.68488 to 0.67943, saving model to results\MobileNetV2_from_scratch_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 35s 274ms/step - accuracy: 0.6723 - loss: 0.5966 - val_accuracy: 0.5887 - val_loss: 0.6794 - learning_rate: 1.0000e-04
# Epoch 3/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.7265 - loss: 0.5576
# Epoch 3: val_loss improved from 0.67943 to 0.67739, saving model to results\MobileNetV2_from_scratch_bs8\best_model.keras
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 35s 277ms/step - accuracy: 0.7265 - loss: 0.5575 - val_accuracy: 0.5887 - val_loss: 0.6774 - learning_rate: 1.0000e-04
# Epoch 4/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.7440 - loss: 0.5549
# Epoch 4: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 34s 269ms/step - accuracy: 0.7441 - loss: 0.5547 - val_accuracy: 0.5887 - val_loss: 0.6796 - learning_rate: 1.0000e-04
# Epoch 5/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.7810 - loss: 0.4676
# Epoch 5: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 34s 267ms/step - accuracy: 0.7809 - loss: 0.4678 - val_accuracy: 0.5887 - val_loss: 0.6854 - learning_rate: 1.0000e-04
# Epoch 6/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.7441 - loss: 0.5335
# Epoch 6: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 34s 270ms/step - accuracy: 0.7442 - loss: 0.5333 - val_accuracy: 0.5887 - val_loss: 0.7002 - learning_rate: 1.0000e-04
# Epoch 7/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.7483 - loss: 0.5028
# Epoch 7: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 34s 271ms/step - accuracy: 0.7484 - loss: 0.5027 - val_accuracy: 0.5887 - val_loss: 0.6913 - learning_rate: 1.0000e-04
# Epoch 8/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.7760 - loss: 0.4678
# Epoch 8: val_loss did not improve from 0.67739
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 35s 273ms/step - accuracy: 0.7760 - loss: 0.4680 - val_accuracy: 0.5887 - val_loss: 0.7090 - learning_rate: 1.0000e-04
# Epoch 9/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.7481 - loss: 0.5113
# Epoch 9: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 35s 279ms/step - accuracy: 0.7482 - loss: 0.5112 - val_accuracy: 0.5887 - val_loss: 0.7262 - learning_rate: 2.0000e-05
# Epoch 10/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.8012 - loss: 0.4633
# Epoch 10: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 34s 264ms/step - accuracy: 0.8012 - loss: 0.4634 - val_accuracy: 0.5887 - val_loss: 0.7303 - learning_rate: 2.0000e-05
# Epoch 11/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.8010 - loss: 0.4191
# Epoch 11: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 255ms/step - accuracy: 0.8009 - loss: 0.4193 - val_accuracy: 0.5887 - val_loss: 0.7448 - learning_rate: 2.0000e-05
# Epoch 12/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.7581 - loss: 0.4776
# Epoch 12: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 32s 254ms/step - accuracy: 0.7583 - loss: 0.4775 - val_accuracy: 0.5887 - val_loss: 0.7470 - learning_rate: 2.0000e-05
# Epoch 13/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.7825 - loss: 0.4515
# Epoch 13: val_loss did not improve from 0.67739
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 34s 271ms/step - accuracy: 0.7826 - loss: 0.4516 - val_accuracy: 0.5887 - val_loss: 0.7601 - learning_rate: 2.0000e-05
# Epoch 14/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.8022 - loss: 0.4170
# Epoch 14: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 36s 280ms/step - accuracy: 0.8022 - loss: 0.4171 - val_accuracy: 0.5887 - val_loss: 0.7883 - learning_rate: 4.0000e-06
# Epoch 15/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.7809 - loss: 0.4726
# Epoch 15: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 36s 282ms/step - accuracy: 0.7809 - loss: 0.4726 - val_accuracy: 0.5887 - val_loss: 0.7956 - learning_rate: 4.0000e-06
# Epoch 16/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.7631 - loss: 0.4926
# Epoch 16: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 35s 277ms/step - accuracy: 0.7632 - loss: 0.4925 - val_accuracy: 0.5887 - val_loss: 0.8080 - learning_rate: 4.0000e-06
# Epoch 17/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.8155 - loss: 0.4437
# Epoch 17: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 35s 278ms/step - accuracy: 0.8154 - loss: 0.4437 - val_accuracy: 0.5887 - val_loss: 0.8340 - learning_rate: 4.0000e-06
# Epoch 18/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.8069 - loss: 0.4268
# Epoch 18: val_loss did not improve from 0.67739
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 7.999999979801942e-07.
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 36s 281ms/step - accuracy: 0.8069 - loss: 0.4269 - val_accuracy: 0.5887 - val_loss: 0.8544 - learning_rate: 4.0000e-06
# Epoch 19/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.7862 - loss: 0.4611
# Epoch 19: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 35s 279ms/step - accuracy: 0.7862 - loss: 0.4611 - val_accuracy: 0.5887 - val_loss: 0.8634 - learning_rate: 8.0000e-07
# Epoch 20/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.7939 - loss: 0.4699
# Epoch 20: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 35s 274ms/step - accuracy: 0.7940 - loss: 0.4697 - val_accuracy: 0.5887 - val_loss: 0.8716 - learning_rate: 8.0000e-07
# Epoch 21/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - accuracy: 0.7904 - loss: 0.4873
# Epoch 21: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 36s 285ms/step - accuracy: 0.7904 - loss: 0.4873 - val_accuracy: 0.5887 - val_loss: 0.8785 - learning_rate: 8.0000e-07
# Epoch 22/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.7760 - loss: 0.5236
# Epoch 22: val_loss did not improve from 0.67739
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 36s 280ms/step - accuracy: 0.7761 - loss: 0.5233 - val_accuracy: 0.5887 - val_loss: 0.8829 - learning_rate: 8.0000e-07
# Epoch 23/100
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step - accuracy: 0.7764 - loss: 0.4698
# Epoch 23: val_loss did not improve from 0.67739
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 1.600000018697756e-07.
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 36s 284ms/step - accuracy: 0.7765 - loss: 0.4697 - val_accuracy: 0.5887 - val_loss: 0.8916 - learning_rate: 8.0000e-07
# Epoch 23: early stopping
# Restoring model weights from the end of the best epoch: 3.
#
# --- MobileNetV2_from_scratch_bs8 Final Test Set Evaluation ---
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 277ms/step
#
# Test Set Classification Report:
#
#                        precision    recall  f1-score   support
#
#        Healty Brinjal       0.00      0.00      0.00       103
# Shoot and Fruit Borer       0.58      1.00      0.74       145
#
#              accuracy                           0.58       248
#             macro avg       0.29      0.50      0.37       248
#          weighted avg       0.34      0.58      0.43       248
#
#
# Updating summary results file...
# c:\Users\dr-basab\Desktop\Research Projects\ADLMODCT\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\dr-basab\Desktop\Research Projects\ADLMODCT\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\dr-basab\Desktop\Research Projects\ADLMODCT\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\dr-basab\Desktop\Research Projects\ADLMODCT\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\dr-basab\Desktop\Research Projects\ADLMODCT\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\dr-basab\Desktop\Research Projects\ADLMODCT\venv\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# --- Experiment for MobileNetV2_from_scratch_bs8 is complete. Best model saved to results\MobileNetV2_from_scratch_bs8\best_model.keras ---
